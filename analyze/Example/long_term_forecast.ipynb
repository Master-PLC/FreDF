# %%
# !pip install scipy seaborn matplotlib cuml-cu11 pyyaml

# %% [markdown]
# # Imports

# %%
import os
import pickle
import re
import shutil
import sys
sys.path.append(os.path.dirname(os.getcwd()))
from itertools import product

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import yaml
from matplotlib.backends.backend_pdf import PdfPages
from tools import load_npy, load_yaml_as_df, load_pkl, exist_metric, exist_stf_metric, inverse_stf_metrics, keep_split, is_full_group, load_metric_from_log

plt.style.use('default')
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
plt.rc('font', family='Arial')
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.size'] = 10

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Baselines local

# %% [markdown]
# ## load data

# %%
root = '/data/home/Licheng/workspace/ProjDF-Meta/results_ML3/baselines'
exp_dirs = os.listdir(root)
exp_dirs = [os.path.join(root, exp_dir) for exp_dir in exp_dirs]

params = ['model', 'pred_len', 'data_id', 'learning_rate', 'batch_size', 'patience', 'individual', 'train_epochs', 'lradj']
metric_names = ['mse', 'mae']

df = []
for exp_dir in exp_dirs:
    runned, setting_dir = exist_metric(exp_dir)
    if not runned:
        continue

    config = load_yaml_as_df(os.path.join(setting_dir, 'config.yaml'))
    metric = load_npy(os.path.join(setting_dir, 'metrics.npy'))
    result = config[params]
    model, individual = config['model'].values[0], config['individual'].values[0]
    if model == 'DLinear' and individual:
        result['model'].values[0] = 'DLinear_Ind'
    result.loc[:, metric_names] = metric[1], metric[0]
    result.loc[:, ['exp_dir']] = exp_dir
    df.append(result)

df = pd.concat(df, ignore_index=True)
df.sort_values(by=['model', 'data_id', 'pred_len'], inplace=True)

# save_root = '/data/home/Licheng/workspace/TSF-CCA/stats_CCA'
# os.makedirs(save_root, exist_ok=True)
# df.to_csv(f"{save_root}/baseline_local.csv", index=False)

df.head(4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 root = '/data/home/Licheng/workspace/ProjDF-Meta/results_ML3/baselines'
# ----> 2 exp_dirs = os.listdir(root)
#       3 exp_dirs = [os.path.join(root, exp_dir) for exp_dir in exp_dirs]
#       5 params = ['model', 'pred_len', 'data_id', 'learning_rate', 'batch_size', 'patience', 'individual', 'train_epochs', 'lradj']
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/home/Licheng/workspace/ProjDF-Meta/results_ML3/baselines'

# %% [markdown]
# ## pre-load

# %%
save_root = '/mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/logs'
df = pd.read_csv(f"{save_root}/baselines_chosen.csv")
df.head()
# Out:
#         model  pred_len data_id  learning_rate  batch_size  patience  \
# 0  Autoformer        96     ECL         0.0005          32         3
# 1  Autoformer       192     ECL         0.0005          32         3
# 2  Autoformer       336     ECL         0.0005          32         3
# 3  Autoformer       720     ECL         0.0005          32         3
# 4  Autoformer        96   ETTh1         0.0005          32         3
#
#    individual  train_epochs  lradj       mse       mae  \
# 0           0            10  type1  0.188511  0.303782
# 1           0            10  type1  0.270894  0.370508
# 2           0            10  type1  0.242762  0.352282
# 3           0            10  type1  0.294784  0.388354
# 4           0            10  type1  0.448748  0.464985
#
#                                              exp_dir
# 0  /data/home/Licheng/workspace/TSF-CCA/results_C...
# 1  /data/home/Licheng/workspace/TSF-CCA/results_C...
# 2  /data/home/Licheng/workspace/TSF-CCA/results_C...
# 3  /data/home/Licheng/workspace/TSF-CCA/results_C...
# 4  /data/home/Licheng/workspace/TSF-CCA/results_C...

# %% [markdown]
# ## analysis

# %%
min_mode = 'each'

df2 = df.copy()

columns = ['model', 'data_id', 'learning_rate', 'batch_size', 'patience', 'individual', 'train_epochs']
if min_mode == 'group':
    mse_mean = df2.groupby(columns)['mse'].mean().reset_index()
    idx = mse_mean.groupby(['model', 'data_id'])['mse'].idxmin()
    best_model = mse_mean.loc[idx]
    df2 = df2.merge(best_model[columns], on=columns, how='inner')
elif min_mode == 'each':
    min_mse_idx = df2.groupby(['model', 'data_id', 'pred_len'])['mse'].idxmin()
    df2 = df2.loc[min_mse_idx]

df2 = df2[['model', 'pred_len', 'data_id', 'mse', 'mae']]

dst_order = ['ETTm1', 'ETTm2', 'ETTh1', 'ETTh2', 'ECL', 'Traffic', 'Weather', 'PEMS03', 'PEMS08']
df2['data_id'] = pd.Categorical(df2['data_id'], categories=dst_order, ordered=True)

model_order = ['TQNet', 'PDF', 'CycleNet', 'PatchTST', 'DLinear', 'Fredformer', 'iTransformer', 'FreTS', 'TimesNet', 'MICN', 'TiDE']
df2 = df2[df2['model'].isin(model_order)]
df2['model'] = pd.Categorical(df2['model'], categories=model_order, ordered=True)

df2_avg = df2.groupby(['model', 'data_id']).mean(numeric_only=True).reset_index()
df2_avg['pred_len'] = 'Avg'
df2 = pd.concat([df2, df2_avg]).reset_index(drop=True)

df2.sort_values(by=['model', 'data_id', 'pred_len'], inplace=True)

df2 = df2.set_index(['data_id', 'pred_len', 'model']).unstack('model').swaplevel(axis=1)
columns = []
for model in df2.columns.levels[0]:
    columns.append((model, 'mse'))
    columns.append((model, 'mae'))
df2 = df2[columns]

# df2.to_excel(f'{save_root}/baselines_local.xlsx')
# df2.to_csv(f'{save_root}/baselines_local.csv')
df2
# Out:
# /tmp/ipykernel_253782/2260451254.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2_avg = df2.groupby(['model', 'data_id']).mean(numeric_only=True).reset_index()
# model                TQNet                 PDF           CycleNet      \
#                        mse       mae       mse       mae      mse mae
# data_id pred_len
# ETTm1   96        0.306602  0.348971  0.320094  0.358292      NaN NaN
#         192       0.352414  0.376268  0.360833  0.379950      NaN NaN
#         336       0.382595  0.397512  0.390477  0.400542      NaN NaN
#         720       0.441163  0.434478  0.451229  0.436571      NaN NaN
#         Avg       0.370693  0.389307  0.380658  0.393839      NaN NaN
# ETTm2   96        0.170291  0.252600  0.174904  0.262821      NaN NaN
#         192       0.233855  0.293836  0.242344  0.305705      NaN NaN
#         336       0.290130  0.331435  0.302503  0.343900      NaN NaN
#         720       0.386822  0.388532  0.401535  0.399057      NaN NaN
#         Avg       0.270274  0.316601  0.280322  0.327871      NaN NaN
# ETTh1   96        0.365111  0.388897  0.374883  0.391447      NaN NaN
#         192       0.427475  0.421499  0.423170  0.419380      NaN NaN
#         336       0.465918  0.448515  0.461447  0.439141      NaN NaN
#         720       0.464051  0.460899  0.483943  0.468018      NaN NaN
#         Avg       0.430639  0.429952  0.435861  0.429496      NaN NaN
# ETTh2   96        0.285516  0.337423  0.287638  0.337379      NaN NaN
#         192       0.361035  0.388219  0.371993  0.389024      NaN NaN
#         336       0.407637  0.422494  0.411470  0.423844      NaN NaN
#         720           NaN NaN     NaN NaN   0.415097  0.432734     0.422140
#         Avg           NaN NaN     NaN NaN   0.370520  0.395437     0.379658
# ECL     96            NaN NaN     NaN NaN   0.152729  0.244039     0.145757
#         192           NaN NaN     NaN NaN   0.164362  0.254401     0.160386
#         336           NaN NaN     NaN NaN   0.179877  0.270527     0.174691
#         720           NaN NaN     NaN NaN   0.209834  0.296626     0.211777
#         Avg           NaN NaN     NaN NaN   0.176700  0.266398     0.173153
# Traffic 96            NaN NaN     NaN NaN        NaN       NaN     1.340927
#         192           NaN NaN     NaN NaN        NaN       NaN     1.248921
#         336           NaN NaN     NaN NaN        NaN       NaN     1.427310
#         720           NaN NaN     NaN NaN        NaN       NaN     1.449898
#         Avg           NaN NaN     NaN NaN        NaN       NaN     1.366764
# Weather 96            NaN NaN     NaN NaN   0.170982  0.213546     0.204312
#         192           NaN NaN     NaN NaN   0.219212  0.254400     0.251164
#         336           NaN NaN     NaN NaN   0.276913  0.295888     0.302679
#         720           NaN NaN     NaN NaN   0.352626  0.346180     0.372369
#         Avg           NaN NaN     NaN NaN   0.254933  0.277503     0.282631
# PEMS03  12            NaN NaN     NaN NaN        NaN       NaN          NaN
#         24            NaN NaN     NaN NaN        NaN       NaN          NaN
#         36            NaN NaN     NaN NaN        NaN       NaN          NaN
#         48            NaN NaN     NaN NaN        NaN       NaN          NaN
#         Avg           NaN NaN     NaN NaN        NaN       NaN          NaN
# PEMS08  12            NaN NaN     NaN NaN        NaN       NaN          NaN
#         24            NaN NaN     NaN NaN        NaN       NaN          NaN
#         36            NaN NaN     NaN NaN        NaN       NaN          NaN
#         48            NaN NaN     NaN NaN        NaN       NaN          NaN
#         Avg           NaN NaN     NaN NaN        NaN       NaN          NaN
#
# model                      FreTS     TimesNet     MICN     TiDE
#                        mae   mse mae      mse mae  mse mae  mse mae
# data_id pred_len
# ETTm1   96        0.362202   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         192       0.397036   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         336       0.413614   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         720       0.452966   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         Avg       0.406455   NaN NaN      NaN NaN  NaN NaN  NaN NaN
# ETTm2   96        0.261524   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         192       0.307138   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         336       0.352310   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         720       0.406060   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         Avg       0.331758   NaN NaN      NaN NaN  NaN NaN  NaN NaN
# ETTh1   96        0.407316   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         192       0.435657   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         336       0.458154   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         720       0.480526   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         Avg       0.445413   NaN NaN      NaN NaN  NaN NaN  NaN NaN
# ETTh2   96        0.350228   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         192       0.398026   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         336       0.430459   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         720       0.441466   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         Avg       0.405045   NaN NaN      NaN NaN  NaN NaN  NaN NaN
# ECL     96        0.237798   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         192       0.251969   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         336       0.266951   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         720       0.298103   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         Avg       0.263705   NaN NaN      NaN NaN  NaN NaN  NaN NaN
# Traffic 96        0.757323   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         192       0.729827   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         336       0.806308   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         720       0.809671   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         Avg       0.775782   NaN NaN      NaN NaN  NaN NaN  NaN NaN
# Weather 96        0.255868   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         192       0.290263   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         336       0.324409   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         720       0.362975   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         Avg       0.308379   NaN NaN      NaN NaN  NaN NaN  NaN NaN
# PEMS03  12             NaN   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         24             NaN   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         36             NaN   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         48             NaN   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         Avg            NaN   NaN NaN      NaN NaN  NaN NaN  NaN NaN
# PEMS08  12             NaN   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         24             NaN   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         36             NaN   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         48             NaN   NaN NaN      NaN NaN  NaN NaN  NaN NaN
#         Avg            NaN   NaN NaN      NaN NaN  NaN NaN  NaN NaN

# %% [markdown]
# # Finetune

# %% [markdown]
# ## load data

# %%
root = '/mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/results_ML3/finetune'
exp_dirs = os.listdir(root)
exp_dirs = [os.path.join(root, exp_dir) for exp_dir in exp_dirs]

params = ['model', 'pred_len', 'data_id', 'learning_rate', 'inner_lr', 'meta_lr', 'rec_lambda', 'auxi_lambda', 'reg_lambda', 'lradj', 'train_epochs', 'patience', 'batch_size', 'auxi_batch_size', 'warmup_steps', 'meta_inner_steps', 'overlap_ratio', 'num_tasks', 'max_norm', 'auxi_loss', 'first_order', 'dropout', 'cycle']
metric_names = ['mse', 'mae', 'cov']

df = []
for exp_dir in exp_dirs:
    if 'MAE' in exp_dir:
        continue
    # if 'Traffic' not in exp_dir and 'ECL' not in exp_dir and 'Weather' not in exp_dir:
    #     continue
    # if 'Traffic' not in exp_dir or 'TQNet' not in exp_dir:
    #     continue
    runned, setting_dir = exist_metric(exp_dir)
    if not runned:
        continue

    config = load_yaml_as_df(os.path.join(setting_dir, 'config.yaml'))
    metric = load_npy(os.path.join(setting_dir, 'metrics.npy'))
    result = config[params]
    if len(metric) == 6:
        log_metrics = load_metric_from_log(os.path.join(exp_dir, 'result_long_term_forecast.txt'))
        cov_loss = log_metrics['cov']
        result.loc[:, metric_names] = metric[1], metric[0], cov_loss
    else:
        result.loc[:, metric_names] = metric[1], metric[0], metric[2]
    result.loc[:, ['meta_type']] = config[['meta_type']] if 'meta_type' in config.columns else 'all'
    result.loc[:, ['exp_dir']] = exp_dir
    df.append(result)

df = pd.concat(df, ignore_index=True)

df.sort_values(by=['model', 'data_id', 'pred_len'], inplace=True)

save_root = '/mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/stats_ML3'
os.makedirs(save_root, exist_ok=True)
df.to_csv(f"{save_root}/finetune_all_results.csv", index=False)

df.head(4)
# Out:
#          model  pred_len data_id  learning_rate  inner_lr  meta_lr  \
# 36  Fredformer        96     ECL          0.002     0.002     0.05
# 37  Fredformer        96     ECL          0.002     0.002     0.05
# 38  Fredformer        96     ECL          0.002     0.002     0.10
# 39  Fredformer        96     ECL          0.002     0.002     0.10
#
#     rec_lambda  auxi_lambda  reg_lambda  lradj  train_epochs  patience  \
# 36         1.0          0.0         0.0  type1           100         5
# 37         1.0          0.0         0.0  type1           100         5
# 38         1.0          0.0         0.0  type1           100         5
# 39         1.0          0.0         0.0  type1           100         5
#
#     batch_size  auxi_batch_size  warmup_steps  meta_inner_steps  \
# 36          32               64           300                 1
# 37          32               64           300                 2
# 38          32               64           300                 1
# 39          32               64           300                 2
#
#     overlap_ratio  num_tasks  max_norm auxi_loss  first_order  dropout  cycle  \
# 36            0.0          3       5.0       MSE            1      0.2     24
# 37            0.0          3       5.0       MSE            1      0.2     24
# 38            0.0          3       5.0       MSE            1      0.2     24
# 39            0.0          3       5.0       MSE            1      0.2     24
#
#          mse       mae       cov meta_type  \
# 36  0.154554  0.245372  0.103599       all
# 37  0.153540  0.244694  0.102987       all
# 38  0.152893  0.244035  0.087282       all
# 39  0.153492  0.244443  0.087609       all
#
#                                               exp_dir
# 36  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 37  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 38  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 39  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...

# %% [markdown]
# ## pre-load

# %%
save_root = '/mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/stats_ML3'
df = pd.read_csv(f'{save_root}/finetune_all_results.csv')

df.head(4)
# Out:
#         model  pred_len data_id  learning_rate  inner_lr  meta_lr  rec_lambda  \
# 0  Fredformer        96     ECL          0.002     0.002     0.05         1.0
# 1  Fredformer        96     ECL          0.002     0.002     0.05         1.0
# 2  Fredformer        96     ECL          0.002     0.002     0.10         1.0
# 3  Fredformer        96     ECL          0.002     0.002     0.10         1.0
#
#    auxi_lambda  reg_lambda  lradj  train_epochs  patience  batch_size  \
# 0          0.0         0.0  type1           100         5          32
# 1          0.0         0.0  type1           100         5          32
# 2          0.0         0.0  type1           100         5          32
# 3          0.0         0.0  type1           100         5          32
#
#    auxi_batch_size  warmup_steps  meta_inner_steps  overlap_ratio  num_tasks  \
# 0               64           300                 1            0.0          3
# 1               64           300                 2            0.0          3
# 2               64           300                 1            0.0          3
# 3               64           300                 2            0.0          3
#
#    max_norm auxi_loss  first_order  dropout  cycle       mse       mae  \
# 0       5.0       MSE            1      0.2     24  0.154554  0.245372
# 1       5.0       MSE            1      0.2     24  0.153540  0.244694
# 2       5.0       MSE            1      0.2     24  0.152893  0.244035
# 3       5.0       MSE            1      0.2     24  0.153492  0.244443
#
#         cov meta_type                                            exp_dir
# 0  0.103599       all  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 1  0.102987       all  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 2  0.087282       all  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 3  0.087609       all  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...

# %% [markdown]
# ## pre-analysis

# %%
df_sort = df.sort_values(by=['model', 'data_id', 'pred_len', 'mse'])[['data_id', 'pred_len', 'mse']].groupby(['data_id', 'pred_len']).head(5)

columns = ['model', 'pred_len', 'data_id', 'mse', 'mae', 'cov', 'learning_rate', 'inner_lr', 'meta_lr', 'auxi_loss', 'rec_lambda', 'auxi_lambda', 'reg_lambda', 'lradj', 'train_epochs', 'patience', 'batch_size', 'auxi_batch_size', 'warmup_steps', 'meta_inner_steps', 'overlap_ratio', 'num_tasks', 'max_norm', 'first_order', 'dropout', 'cycle']

df_sort = df.sort_values(by=['model', 'data_id', 'pred_len', 'mse']).groupby(['data_id', 'num_tasks', 'meta_inner_steps', 'pred_len']).head(5)
df_sort = df_sort[df_sort['data_id'].isin(['Traffic'])]
df_sort[columns]

for i, row in df_sort.iterrows():
    # exp_dir = row['exp_dir']
    mse = row['mse']
    print(f"Data ID: {row['data_id']}, Pred Len: {row['pred_len']}, MSE: {mse:.7f}, inner steps: {row['meta_inner_steps']}, ntask: {row['num_tasks']}, lr: {row['learning_rate']}, meta_lr: {row['meta_lr']}, bs: {row['batch_size']}, auxi_bs: {row['auxi_batch_size']}, warmup: {row['warmup_steps']}")
    # print(exp_dir)
# Out:
# Data ID: Traffic, Pred Len: 96, MSE: 0.4160268, inner steps: 2, ntask: 4, lr: 0.005, meta_lr: 0.1, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 96, MSE: 0.4163281, inner steps: 1, ntask: 3, lr: 0.005, meta_lr: 0.15, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 96, MSE: 0.4163281, inner steps: 1, ntask: 3, lr: 0.005, meta_lr: 0.15, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 96, MSE: 0.4166446, inner steps: 1, ntask: 3, lr: 0.005, meta_lr: 0.2, bs: 16, auxi_bs: 64, warmup: 300
# Data ID: Traffic, Pred Len: 96, MSE: 0.4168713, inner steps: 2, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 96, MSE: 0.4169695, inner steps: 2, ntask: 3, lr: 0.004, meta_lr: 0.03, bs: 16, auxi_bs: 64, warmup: 300
# Data ID: Traffic, Pred Len: 96, MSE: 0.4169772, inner steps: 1, ntask: 3, lr: 0.005, meta_lr: 0.1, bs: 16, auxi_bs: 64, warmup: 200
# Data ID: Traffic, Pred Len: 96, MSE: 0.4169828, inner steps: 2, ntask: 3, lr: 0.005, meta_lr: 0.15, bs: 16, auxi_bs: 64, warmup: 300
# Data ID: Traffic, Pred Len: 96, MSE: 0.4169938, inner steps: 1, ntask: 3, lr: 0.005, meta_lr: 0.05, bs: 16, auxi_bs: 64, warmup: 300
# Data ID: Traffic, Pred Len: 96, MSE: 0.4170468, inner steps: 2, ntask: 3, lr: 0.005, meta_lr: 0.1, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 96, MSE: 0.4170468, inner steps: 2, ntask: 3, lr: 0.005, meta_lr: 0.1, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 96, MSE: 0.4171279, inner steps: 2, ntask: 3, lr: 0.005, meta_lr: 0.1, bs: 16, auxi_bs: 64, warmup: 200
# Data ID: Traffic, Pred Len: 96, MSE: 0.4171508, inner steps: 2, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 96, MSE: 0.4171654, inner steps: 1, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 96, MSE: 0.4171686, inner steps: 2, ntask: 4, lr: 0.005, meta_lr: 0.1, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 96, MSE: 0.4178177, inner steps: 1, ntask: 4, lr: 0.005, meta_lr: 0.1, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 96, MSE: 0.4178662, inner steps: 2, ntask: 4, lr: 0.005, meta_lr: 0.05, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 96, MSE: 0.4179190, inner steps: 1, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 96, MSE: 0.4181612, inner steps: 1, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 96, MSE: 0.4189978, inner steps: 1, ntask: 4, lr: 0.005, meta_lr: 0.05, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 96, MSE: 0.4215452, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 400
# Data ID: Traffic, Pred Len: 96, MSE: 0.4218882, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 96, MSE: 0.4227735, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 300
# Data ID: Traffic, Pred Len: 96, MSE: 0.4235972, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.005, bs: 8, auxi_bs: 32, warmup: 400
# Data ID: Traffic, Pred Len: 96, MSE: 0.4236506, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 300
# Data ID: Traffic, Pred Len: 96, MSE: 0.4245792, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 96, MSE: 0.4252341, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 96, MSE: 0.4610286, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 96, MSE: 0.4610899, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 96, MSE: 0.4612242, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 192, MSE: 0.4318241, inner steps: 1, ntask: 3, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 192, MSE: 0.4322846, inner steps: 1, ntask: 3, lr: 0.005, meta_lr: 0.05, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 192, MSE: 0.4326603, inner steps: 2, ntask: 3, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 192, MSE: 0.4339403, inner steps: 2, ntask: 3, lr: 0.005, meta_lr: 0.05, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 192, MSE: 0.4344437, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 192, MSE: 0.4347271, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 400
# Data ID: Traffic, Pred Len: 192, MSE: 0.4353141, inner steps: 1, ntask: 3, lr: 0.005, meta_lr: 0.2, bs: 16, auxi_bs: 64, warmup: 300
# Data ID: Traffic, Pred Len: 192, MSE: 0.4353633, inner steps: 2, ntask: 3, lr: 0.004, meta_lr: 0.02, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 192, MSE: 0.4354542, inner steps: 2, ntask: 3, lr: 0.004, meta_lr: 0.03, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 192, MSE: 0.4354542, inner steps: 2, ntask: 3, lr: 0.004, meta_lr: 0.03, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 192, MSE: 0.4355083, inner steps: 1, ntask: 3, lr: 0.003, meta_lr: 0.02, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 192, MSE: 0.4355236, inner steps: 1, ntask: 3, lr: 0.004, meta_lr: 0.02, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 192, MSE: 0.4355587, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 192, MSE: 0.4368793, inner steps: 1, ntask: 4, lr: 0.005, meta_lr: 0.1, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 192, MSE: 0.4370686, inner steps: 2, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 192, MSE: 0.4376323, inner steps: 1, ntask: 4, lr: 0.005, meta_lr: 0.003, bs: 8, auxi_bs: 32, warmup: 300
# Data ID: Traffic, Pred Len: 192, MSE: 0.4376397, inner steps: 1, ntask: 4, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 300
# Data ID: Traffic, Pred Len: 192, MSE: 0.4379297, inner steps: 2, ntask: 4, lr: 0.005, meta_lr: 0.1, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 192, MSE: 0.4380503, inner steps: 2, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 192, MSE: 0.4382932, inner steps: 1, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 192, MSE: 0.4385044, inner steps: 1, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 192, MSE: 0.4387246, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 192, MSE: 0.4391534, inner steps: 2, ntask: 4, lr: 0.005, meta_lr: 0.05, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 192, MSE: 0.4397587, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.003, bs: 8, auxi_bs: 32, warmup: 300
# Data ID: Traffic, Pred Len: 192, MSE: 0.4398510, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 192, MSE: 0.4398769, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 300
# Data ID: Traffic, Pred Len: 192, MSE: 0.4399244, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 400
# Data ID: Traffic, Pred Len: 192, MSE: 0.4401408, inner steps: 2, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 192, MSE: 0.4792096, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 192, MSE: 0.4792290, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 336, MSE: 0.4463018, inner steps: 2, ntask: 3, lr: 0.004, meta_lr: 0.01, bs: 16, auxi_bs: 64, warmup: 300
# Data ID: Traffic, Pred Len: 336, MSE: 0.4463243, inner steps: 1, ntask: 3, lr: 0.004, meta_lr: 0.01, bs: 16, auxi_bs: 64, warmup: 300
# Data ID: Traffic, Pred Len: 336, MSE: 0.4463505, inner steps: 2, ntask: 3, lr: 0.004, meta_lr: 0.01, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 336, MSE: 0.4463505, inner steps: 2, ntask: 3, lr: 0.004, meta_lr: 0.01, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 336, MSE: 0.4465142, inner steps: 1, ntask: 3, lr: 0.004, meta_lr: 0.01, bs: 16, auxi_bs: 64, warmup: 200
# Data ID: Traffic, Pred Len: 336, MSE: 0.4465725, inner steps: 1, ntask: 3, lr: 0.004, meta_lr: 0.01, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 336, MSE: 0.4465725, inner steps: 1, ntask: 3, lr: 0.004, meta_lr: 0.01, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 336, MSE: 0.4467043, inner steps: 2, ntask: 3, lr: 0.003, meta_lr: 0.03, bs: 16, auxi_bs: 64, warmup: 300
# Data ID: Traffic, Pred Len: 336, MSE: 0.4467729, inner steps: 2, ntask: 3, lr: 0.004, meta_lr: 0.01, bs: 16, auxi_bs: 64, warmup: 150
# Data ID: Traffic, Pred Len: 336, MSE: 0.4468243, inner steps: 1, ntask: 3, lr: 0.003, meta_lr: 0.03, bs: 16, auxi_bs: 64, warmup: 300
# Data ID: Traffic, Pred Len: 336, MSE: 0.4516176, inner steps: 2, ntask: 4, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 336, MSE: 0.4520017, inner steps: 1, ntask: 4, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 400
# Data ID: Traffic, Pred Len: 336, MSE: 0.4520696, inner steps: 1, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 336, MSE: 0.4525532, inner steps: 2, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 336, MSE: 0.4528812, inner steps: 1, ntask: 4, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 300
# Data ID: Traffic, Pred Len: 336, MSE: 0.4530212, inner steps: 1, ntask: 4, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 300
# Data ID: Traffic, Pred Len: 336, MSE: 0.4530427, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 400
# Data ID: Traffic, Pred Len: 336, MSE: 0.4533018, inner steps: 2, ntask: 4, lr: 0.005, meta_lr: 0.05, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 336, MSE: 0.4533070, inner steps: 1, ntask: 4, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 400
# Data ID: Traffic, Pred Len: 336, MSE: 0.4542299, inner steps: 2, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 336, MSE: 0.4545743, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.003, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 336, MSE: 0.4546279, inner steps: 2, ntask: 4, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 336, MSE: 0.4551429, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.005, bs: 8, auxi_bs: 32, warmup: 400
# Data ID: Traffic, Pred Len: 336, MSE: 0.4553217, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 336, MSE: 0.4562649, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 336, MSE: 0.4563813, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 300
# Data ID: Traffic, Pred Len: 336, MSE: 0.4565772, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 336, MSE: 0.4924472, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 336, MSE: 0.4924645, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 336, MSE: 0.4925055, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 720, MSE: 0.4813718, inner steps: 2, ntask: 3, lr: 0.004, meta_lr: 0.03, bs: 16, auxi_bs: 64, warmup: 300
# Data ID: Traffic, Pred Len: 720, MSE: 0.4817941, inner steps: 2, ntask: 3, lr: 0.005, meta_lr: 0.1, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 720, MSE: 0.4826706, inner steps: 1, ntask: 3, lr: 0.005, meta_lr: 0.1, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 720, MSE: 0.4829443, inner steps: 1, ntask: 3, lr: 0.004, meta_lr: 0.03, bs: 16, auxi_bs: 64, warmup: 300
# Data ID: Traffic, Pred Len: 720, MSE: 0.4841320, inner steps: 1, ntask: 3, lr: 0.005, meta_lr: 0.1, bs: 16, auxi_bs: 64, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.4844379, inner steps: 2, ntask: 3, lr: 0.005, meta_lr: 0.03, bs: 16, auxi_bs: 64, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.4847221, inner steps: 1, ntask: 4, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.4850043, inner steps: 2, ntask: 3, lr: 0.005, meta_lr: 0.03, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 720, MSE: 0.4851903, inner steps: 1, ntask: 3, lr: 0.004, meta_lr: 0.03, bs: 16, auxi_bs: 64, warmup: 100
# Data ID: Traffic, Pred Len: 720, MSE: 0.4853643, inner steps: 1, ntask: 3, lr: 0.005, meta_lr: 0.03, bs: 16, auxi_bs: 64, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.4874941, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 720, MSE: 0.4875635, inner steps: 2, ntask: 3, lr: 0.004, meta_lr: 0.01, bs: 16, auxi_bs: 64, warmup: 150
# Data ID: Traffic, Pred Len: 720, MSE: 0.4884257, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 720, MSE: 0.4888265, inner steps: 1, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.4889579, inner steps: 2, ntask: 4, lr: 0.005, meta_lr: 0.05, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.4891411, inner steps: 1, ntask: 4, lr: 0.005, meta_lr: 0.005, bs: 8, auxi_bs: 32, warmup: 400
# Data ID: Traffic, Pred Len: 720, MSE: 0.4894238, inner steps: 1, ntask: 4, lr: 0.005, meta_lr: 0.005, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.4906624, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.005, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.4907147, inner steps: 1, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.4916969, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.003, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.4922588, inner steps: 2, ntask: 4, lr: 0.004, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.4930030, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.005, bs: 8, auxi_bs: 32, warmup: 300
# Data ID: Traffic, Pred Len: 720, MSE: 0.4964632, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 300
# Data ID: Traffic, Pred Len: 720, MSE: 0.4989269, inner steps: 1, ntask: 5, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.5281220, inner steps: 2, ntask: 4, lr: 0.005, meta_lr: 0.1, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.5286868, inner steps: 2, ntask: 4, lr: 0.005, meta_lr: 0.05, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.5290122, inner steps: 2, ntask: 4, lr: 0.005, meta_lr: 0.03, bs: 8, auxi_bs: 32, warmup: 200
# Data ID: Traffic, Pred Len: 720, MSE: 0.5333521, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100
# Data ID: Traffic, Pred Len: 720, MSE: 0.5349575, inner steps: 1, ntask: 2, lr: 0.005, meta_lr: 0.01, bs: 8, auxi_bs: 32, warmup: 100

# %% [markdown]
# ## analysis

# %%
min_mode = 'each'

df2 = df.copy()
df2 = df2[df2.auxi_loss == 'MSE']
df2 = df2[df2.meta_type == 'all']
df2 = df2[df2.first_order == 1]

columns = ['model', 'data_id', 'learning_rate', 'alpha', 'rank_ratio', 'align_type', 'individual']
if min_mode == 'group':
    mse_mean = df2.groupby(columns)['mse'].mean().reset_index()
    idx = mse_mean.groupby(['model', 'data_id'])['mse'].idxmin()
    best_model = mse_mean.loc[idx]
    df2 = df2.merge(best_model[columns], on=columns, how='inner')
elif min_mode == 'each':
    min_mse_idx = df2.groupby(['model', 'data_id', 'pred_len'])['mse'].idxmin()
    df2 = df2.loc[min_mse_idx]
elif min_mode == 'sum':
    # 新增：mse+mae最小
    df2['sum_error'] = df2['mse'] + df2['mae']
    min_sum_idx = df2.groupby(['model', 'data_id', 'pred_len'])['sum_error'].idxmin()
    df2 = df2.loc[min_sum_idx]
    df2 = df2.drop(columns=['sum_error'])

columns = ['model', 'pred_len', 'data_id', 'mse', 'mae', 'cov', 'learning_rate', 'inner_lr', 'meta_lr', 'auxi_loss', 'rec_lambda', 'auxi_lambda', 'reg_lambda', 'lradj', 'train_epochs', 'patience', 'batch_size', 'auxi_batch_size', 'warmup_steps', 'meta_inner_steps', 'overlap_ratio', 'num_tasks', 'max_norm', 'first_order', 'dropout', 'cycle', 'meta_type', 'exp_dir']
df2 = df2[columns]

dst_order = ['ETTm1', 'ETTm2', 'ETTh1', 'ETTh2', 'ECL', 'Traffic', 'Weather', 'PEMS03', 'PEMS08']
df2['data_id'] = pd.Categorical(df2['data_id'], categories=dst_order, ordered=True)

model_order = ['TQNet', 'PDF', 'Fredformer', 'iTransformer']
df2['model'] = pd.Categorical(df2['model'], categories=model_order, ordered=True)
df2.sort_values(by=['model', 'data_id', 'pred_len'], inplace=True)

save_root = '/mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/stats_ML3'
os.makedirs(save_root, exist_ok=True)
df2.to_csv(f"{save_root}/finetune_best.csv", index=False)

# print(df2)
df2_avg = df2.groupby(['model', 'data_id']).mean(numeric_only=True).reset_index()
df2_avg['pred_len'] = 'Avg'

df2 = pd.concat([df2, df2_avg]).reset_index(drop=True)

# pl_order = [96, 192, 336, 720, 'Avg']
# df2['pred_len'] = pd.Categorical(df2['pred_len'], categories=pl_order, ordered=True)

df2.sort_values(by=['data_id', 'model', 'pred_len'], inplace=True)
df2.dropna(inplace=True, thresh=5)
df2
# Out:
# /tmp/ipykernel_9998/111332612.py:39: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2_avg = df2.groupby(['model', 'data_id']).mean(numeric_only=True).reset_index()
#             model pred_len  data_id       mse       mae       cov  \
# 0           TQNet       96    ETTm1  0.306602  0.348971  0.121591
# 1           TQNet      192    ETTm1  0.352414  0.376268  0.287309
# 2           TQNet      336    ETTm1  0.382595  0.397512  0.169736
# 3           TQNet      720    ETTm1  0.441163  0.434478  0.222437
# 115         TQNet      Avg    ETTm1  0.370693  0.389307  0.200268
# 36            PDF       96    ETTm1  0.320094  0.358292  0.162693
# 37            PDF      192    ETTm1  0.360833  0.379950  0.212361
# 38            PDF      336    ETTm1  0.390477  0.400542  0.250300
# 39            PDF      720    ETTm1  0.451229  0.436571  0.310318
# 124           PDF      Avg    ETTm1  0.380658  0.393839  0.233918
# 63     Fredformer       96    ETTm1  0.311762  0.353145  0.079158
# 64     Fredformer      192    ETTm1  0.358952  0.379518  0.178687
# 65     Fredformer      336    ETTm1  0.390576  0.403195  0.138348
# 66     Fredformer      720    ETTm1  0.449709  0.437687  0.200003
# 133    Fredformer      Avg    ETTm1  0.377750  0.393386  0.149049
# 87   iTransformer       96    ETTm1  0.322717  0.362202  0.170924
# 88   iTransformer      192    ETTm1  0.384773  0.397036  0.190982
# 89   iTransformer      336    ETTm1  0.415041  0.413614  0.190248
# 90   iTransformer      720    ETTm1  0.479984  0.452966  0.289373
# 142  iTransformer      Avg    ETTm1  0.400629  0.406455  0.210381
# 4           TQNet       96    ETTm2  0.170291  0.252600  0.054238
# 5           TQNet      192    ETTm2  0.233855  0.293836  0.070129
# 6           TQNet      336    ETTm2  0.290130  0.331435  0.148422
# 7           TQNet      720    ETTm2  0.386822  0.388532  0.143924
# 60            PDF      192  Weather  0.225431  0.259884  0.071219
# 61            PDF      336  Weather  0.279804  0.298935  0.090805
# 62            PDF      720  Weather  0.356894  0.347133  0.179830
# 130           PDF      Avg  Weather  0.259451  0.281072  0.098238
# 83     Fredformer       96  Weather  0.170982  0.213546  0.071181
# 84     Fredformer      192  Weather  0.219212  0.254400  0.096636
# 85     Fredformer      336  Weather  0.276913  0.295888  0.079814
# 86     Fredformer      720  Weather  0.352626  0.346180  0.107080
# 139    Fredformer      Avg  Weather  0.254933  0.277503  0.088678
# 111  iTransformer       96  Weather  0.171803  0.210620  0.097768
# 112  iTransformer      192  Weather  0.220823  0.254083  0.092050
# 113  iTransformer      336  Weather  0.277273  0.296157  0.141822
# 114  iTransformer      720  Weather  0.356461  0.348061  0.185640
# 148  iTransformer      Avg  Weather  0.256590  0.277230  0.129320
# 28          TQNet       12   PEMS03  0.064309  0.167092  0.037420
# 29          TQNet       24   PEMS03  0.080374  0.188680  0.048414
# 30          TQNet       36   PEMS03  0.097987  0.208369  0.046161
# 31          TQNet       48   PEMS03  0.111981  0.223476  0.053002
# 122         TQNet      Avg   PEMS03  0.088663  0.196904  0.046249
# 32          TQNet       12   PEMS08  0.074487  0.175849  0.044302
# 33          TQNet       24   PEMS08  0.104101  0.207774  0.051482
# 34          TQNet       36   PEMS08  0.134275  0.236954  0.062219
# 35          TQNet       48   PEMS08  0.168359  0.263294  0.067871
# 123         TQNet      Avg   PEMS08  0.120305  0.220968  0.056469
#
#      learning_rate  inner_lr  meta_lr auxi_loss  rec_lambda  auxi_lambda  \
# 0         0.001000  0.001000  0.10000       MSE         1.0          0.0
# 1         0.001000  0.001000  0.01000       MSE         1.0          0.0
# 2         0.001000  0.001000  0.20000       MSE         1.0          0.0
# 3         0.001000  0.001000  0.20000       MSE         1.0          0.0
# 115       0.001000  0.001000  0.12750       NaN         1.0          0.0
# 36        0.002000  0.002000  0.05000       MSE         1.0          0.0
# 37        0.001000  0.001000  0.05000       MSE         1.0          0.0
# 38        0.002000  0.002000  0.05000       MSE         1.0          0.0
# 39        0.002000  0.002000  0.05000       MSE         1.0          0.0
# 124       0.001750  0.001750  0.05000       NaN         1.0          0.0
# 63        0.002000  0.002000  0.25000       MSE         1.0          0.0
# 64        0.010000  0.010000  0.10000       MSE         1.0          0.0
# 65        0.005000  0.005000  0.30000       MSE         1.0          0.0
# 66        0.005000  0.005000  0.25000       MSE         1.0          0.0
# 133       0.005500  0.005500  0.22500       NaN         1.0          0.0
# 87        0.002000  0.002000  0.05000       MSE         1.0          0.0
# 88        0.002000  0.002000  0.10000       MSE         1.0          0.0
# 89        0.005000  0.005000  0.20000       MSE         1.0          0.0
# 90        0.002000  0.002000  0.10000       MSE         1.0          0.0
# 142       0.002750  0.002750  0.11250       NaN         1.0          0.0
# 4         0.000200  0.000200  0.20000       MSE         1.0          0.0
# 5         0.000200  0.000200  0.20000       MSE         1.0          0.0
# 6         0.000200  0.000200  0.10000       MSE         1.0          0.0
# 7         0.000200  0.000200  0.20000       MSE         1.0          0.0
# 116       0.000200  0.000200  0.17500       NaN         1.0          0.0
# 40        0.000500  0.000500  0.20000       MSE         1.0          0.0
# 41        0.000500  0.000500  0.20000       MSE         1.0          0.0
# 42        0.000500  0.000500  0.05000       MSE         1.0          0.0
# 43        0.000500  0.000500  0.20000       MSE         1.0          0.0
# 125       0.000500  0.000500  0.16250       NaN         1.0          0.0
# 67        0.004000  0.004000  0.20000       MSE         1.0          0.0
# 68        0.002000  0.002000  0.20000       MSE         1.0          0.0
#
0.002000  0.002000  0.05000       MSE         1.0          0.0
# 57        0.002000  0.002000  0.05000       MSE         1.0          0.0
# 58        0.002000  0.002000  0.05000       MSE         1.0          0.0
# 129       0.002000  0.002000  0.05000       NaN         1.0          0.0
# 107       0.005000  0.005000  0.00100       MSE         1.0          0.0
# 108       0.005000  0.005000  0.01000       MSE         1.0          0.0
# 109       0.005000  0.005000  0.01000       MSE         1.0          0.0
# 110       0.005000  0.005000  0.01000       MSE         1.0          0.0
# 147       0.005000  0.005000  0.00775       NaN         1.0          0.0
# 24        0.002000  0.002000  0.10000       MSE         1.0          0.0
# 25        0.002000  0.002000  0.02000       MSE         1.0          0.0
# 26        0.002000  0.002000  0.05000       MSE         1.0          0.0
# 27        0.002000  0.002000  0.20000       MSE         1.0          0.0
# 121       0.002000  0.002000  0.09250       NaN         1.0          0.0
# 59        0.002000  0.002000  0.20000       MSE         1.0          0.0
# 60        0.002000  0.002000  0.20000       MSE         1.0          0.0
# 61        0.002000  0.002000  0.20000       MSE         1.0          0.0
# 62        0.002000  0.002000  0.05000       MSE         1.0          0.0
# 130       0.002000  0.002000  0.16250       NaN         1.0          0.0
# 83        0.005000  0.005000  0.05000       MSE         1.0          0.0
# 84        0.005000  0.005000  0.05000       MSE         1.0          0.0
# 85        0.005000  0.005000  0.20000       MSE         1.0          0.0
# 86        0.005000  0.005000  0.20000       MSE         1.0          0.0
# 139       0.005000  0.005000  0.12500       NaN         1.0          0.0
# 111       0.001000  0.001000  0.05000       MSE         1.0          0.0
# 112       0.001000  0.001000  0.10000       MSE         1.0          0.0
# 113       0.001000  0.001000  0.05000       MSE         1.0          0.0
# 114       0.001000  0.001000  0.05000       MSE         1.0          0.0
# 148       0.001000  0.001000  0.06250       NaN         1.0          0.0
# 28        0.002000  0.002000  0.01500       MSE         1.0          0.0
# 29        0.002000  0.002000  0.01500       MSE         1.0          0.0
# 30        0.002000  0.002000  0.05000       MSE         1.0          0.0
# 31        0.002000  0.002000  0.05000       MSE         1.0          0.0
# 122       0.002000  0.002000  0.03250       NaN         1.0          0.0
# 32        0.003000  0.003000  0.01000       MSE         1.0          0.0
# 33        0.003000  0.003000  0.02000       MSE         1.0          0.0
# 34        0.003000  0.003000  0.02000       MSE         1.0          0.0
# 35        0.003000  0.003000  0.03000       MSE         1.0          0.0
# 123       0.003000  0.003000  0.02000       NaN         1.0          0.0
#
#      reg_lambda  lradj  train_epochs  patience  batch_size  auxi_batch_size  \
# 0           0.0  type1          30.0       5.0        32.0             64.0
# 1           0.0  type1          30.0       5.0        32.0             64.0
# 2           0.0  type1          30.0       5.0        32.0             64.0
# 3           0.0  type1          30.0       5.0        32.0             64.0
# 115         0.0    NaN          30.0       5.0        32.0             64.0
# 36          0.0  type1         100.0      10.0        32.0             64.0
# 37          0.0  type1         100.0      10.0        32.0             64.0
# 38          0.0  type1         100.0      10.0        32.0             64.0
# 39          0.0  type1         100.0      10.0        32.0             64.0
# 124         0.0    NaN         100.0      10.0        32.0             64.0
# 63          0.0  type3         100.0      10.0       128.0             64.0
# 64          0.0  type1         100.0      10.0        32.0             64.0
# 65          0.0    TST         100.0      10.0       128.0             64.0
# 66          0.0    TST         100.0      10.0       128.0             64.0
# 133         0.0    NaN         100.0      10.0       104.0             64.0
# 87          0.0  type1          10.0       3.0        32.0             64.0
# 88          0.0  type1          10.0       3.0        32.0             64.0
# 89          0.0  type1          10.0       3.0        32.0             64.0
# 90          0.0  type1          10.0       3.0        32.0             64.0
# 142         0.0    NaN          10.0       3.0        32.0             64.0
# 4           0.0  type1          30.0       5.0        32.0             64.0
# 5           0.0  type1          30.0       5.0        32.0             64.0
# 6           0.0  type1          30.0       5.0        32.0             64.0
# 7           0.0  type1          30.0       5.0        32.0             64.0
# 116         0.0    NaN          30.0       5.0        32.0             64.0
# 40          0.0  type1         100.0      10.0        32.0             64.0
# 41          0.0  type1         100.0      10.0        32.0             64.0
# 42          0.0  type1         100.0      10.0        32.0             64.0
# 43          0.0  type1         100.0      10.0        32.0             64.0
# 125         0.0    NaN         100.0      10.0        32.0             64.0
# 67          0.0    TST         100.0      10.0       128.0             64.0
# 68          0.0    TST         100.0      10.0       128.0             64.0
# 69          0.0    TST         100.0      10.0       128.0             64.0
# 70          0.0    TST         100.0      10.0        32.0             64.0
# 134         0.0    NaN         100.0      10.0       104.0             64.0
# 91          0.0  type1          10.0       3.0        32.0             64.0
# 92          0.0  type1          10.0       3.0        32.0             64.0
# 93          0.0  type1          10.0       3.0        32.0             64.0
# 94          0.0  type1          10.0       3.0        32.0             64.0
# 143         0.0    NaN          10.0       3.0        32.0             64.0
# 8           0.0  type1          30.0       5.0        32.0             64.0
# 9           0.0  type1          30.0       5.0        32.0             64.0
# 10          0.0  type1          30.0       5.0        32.0             64.0
# 11          0.0  type1          30.0       5.0        32.0             64.0
# 117         0.0    NaN          30.0       5.0        32.0             64.0
# 44          0.0  type1         100.0      10.0        32.0             64.0
# 45          0.0  type1         100.0      10.0        32.0             64.0
# 46          0.0  type1         100.0      10.0        32.0             64.0
# 47          0.0  type1         100.0      10.0        32.0             64.0
# 126         0.0    NaN         100.0      10.0        32.0             64.0
# 71          0.0  type3         100.0      10.0       128.0             64.0
# 72          0.0  type1         100.0      10.0       128.0             64.0
# 73          0.0  type3         100.0      10.0        32.0             64.0
# 74          0.0  type3         100.0      10.0       128.0             64.0
# 135         0.0    NaN         100.0      10.0       104.0             64.0
# 95          0.0  type1          10.0       3.0        32.0             64.0
# 96          0.0  type1          10.0       3.0        32.0             64.0
# 97          0.0  type3          10.0       3.0        32.0             64.0
# 98          0.0  type1          10.0       3.0        32.0             64.0
# 144         0.0    NaN          10.0       3.0        32.0             64.0
# 12          0.0  type1          30.0       5.0        32.0             64.0
# 13          0.0  type1          30.0       5.0        32.0             64.0
# 14          0.0  type1          30.0       5.0        32.0             64.0
# 15          0.0  type1          30.0       5.0        32.0             64.0
# 118         0.0    NaN          30.0       5.0        32.0             64.0
# 48          0.0  type1         100.0      10.0        32.0             64.0
# 49          0.0  type1         100.0      10.0        32.0             64.0
# 50          0.0  type1         100.0      10.0        32.0             64.0
# 51          0.0  type1         100.0      10.0        32.0             64.0
# 127         0.0    NaN         100.0      10.0        32.0             64.0
# 75          0.0  type1         100.0      10.0        32.0             64.0
# 76          0.0  type1         100.0      10.0        32.0             64.0
# 77          0.0  type1         100.0      10.0        32.0             64.0
# 78          0.0  type1         100.0      10.0        32.0             64.0
# 136         0.0    NaN         100.0      10.0        32.0             64.0
# 99          0.0  type1          10.0       3.0        32.0             64.0
# 100         0.0  type1          10.0       3.0        32.0             64.0
# 101         0.0  type1          10.0       3.0        32.0             64.0
# 102         0.0  type1          10.0       3.0        32.0             64.0
# 145         0.0    NaN          10.0       3.0        32.0             64.0
# 16          0.0  type1          30.0       5.0        16.0             64.0
# 17          0.0  type1          30.0       5.0        16.0             64.0
# 18          0.0  type1          30.0       5.0        16.0             64.0
# 19          0.0  type1          30.0       5.0        16.0             64.0
# 119         0.0    NaN          30.0       5.0        16.0             64.0
# 52          0.0    TST         100.0      10.0        32.0             64.0
# 53          0.0  type1         100.0      10.0        32.0             64.0
# 54          0.0  type1         100.0      10.0        32.0             64.0
# 55          0.0  type1         100.0      10.0        32.0             64.0
# 128         0.0    NaN         100.0      10.0        32.0             64.0
# 79          0.0  type1         100.0       5.0        32.0             64.0
# 80          0.0  type1         100.0       5.0        32.0             64.0
# 81          0.0  type1         100.0       5.0        32.0             64.0
# 82          0.0  type1         100.0       5.0        32.0             64.0
# 137         0.0    NaN         100.0       5.0        32.0             64.0
# 103         0.0  type1          10.0       3.0        32.0             64.0
# 104         0.0  type1          10.0       3.0        32.0             64.0
# 105         0.0  type1          10.0       3.0        32.0             64.0
# 106         0.0  type1          10.0       3.0        32.0             64.0
# 146         0.0    NaN          10.0       3.0        32.0             64.0
# 20          0.0  type3          30.0       5.0        16.0             64.0
# 21          0.0  type3          30.0       5.0        16.0             64.0
# 22          0.0  type3          30.0       5.0        16.0             64.0
# 23          0.0  type3          30.0       5.0        16.0             64.0
# 120         0.0    NaN          30.0       5.0        16.0             64.0
# 56          0.0  type1         100.0      10.0        32.0             64.0
# 57          0.0  type1         100.0      10.0        32.0             64.0
# 58          0.0  type1         100.0      10.0        32.0             64.0
# 129         0.0    NaN         100.0      10.0        32.0             64.0
# 107         0.0  type1          30.0      10.0        16.0             64.0
# 108         0.0    TST          10.0      10.0         8.0             32.0
# 109         0.0    TST          10.0      10.0         8.0             32.0
# 110         0.0    TST          10.0      10.0         8.0             32.0
# 147         0.0    NaN          15.0      10.0        10.0             40.0
# 24          0.0  type1          30.0       5.0        32.0             64.0
# 25          0.0  type1          30.0       5.0        32.0             64.0
# 26          0.0  type1          30.0       5.0        32.0             64.0
# 27          0.0  type1          30.0       5.0        32.0             64.0
# 121         0.0    NaN          30.0       5.0        32.0             64.0
# 59          0.0  type1         100.0      10.0        32.0             64.0
# 60          0.0  type1         100.0      10.0        32.0             64.0
# 61          0.0  type1         100.0      10.0        32.0             64.0
# 62          0.0  type1         100.0      10.0        32.0             64.0
# 130         0.0    NaN         100.0      10.0        32.0             64.0
# 83          0.0  type3         100.0       5.0        32.0             64.0
# 84          0.0  type3         100.0       5.0        32.0             64.0
# 85          0.0  type3         100.0       5.0        32.0             64.0
# 86          0.0  type3         100.0       5.0        32.0             64.0
# 139         0.0    NaN         100.0       5.0        32.0             64.0
# 111         0.0  type1          30.0      10.0       128.0             64.0
# 112         0.0  type1          30.0      10.0       128.0             64.0
# 113         0.0  type1          30.0      10.0       128.0             64.0
# 114         0.0  type1          30.0      10.0       128.0             64.0
# 148         0.0    NaN          30.0      10.0       128.0             64.0
# 28          0.0  type1          30.0       5.0        32.0             64.0
# 29          0.0  type1          30.0       5.0        32.0             64.0
# 30          0.0  type1          30.0       5.0        32.0             64.0
# 31          0.0  type1          30.0       5.0        32.0             64.0
# 122         0.0    NaN          30.0       5.0        32.0             64.0
# 32          0.0  type1          30.0       5.0        32.0             64.0
# 33          0.0  type1          30.0       5.0        32.0             64.0
# 34          0.0  type1          30.0       5.0        32.0             64.0
# 35          0.0  type1          30.0       5.0        32.0             64.0
# 123         0.0    NaN          30.0       5.0        32.0             64.0
#
#      warmup_steps  meta_inner_steps  overlap_ratio  num_tasks  max_norm  \
# 0           500.0          1.000000            0.0       2.00       5.0
# 1           500.0          3.000000            0.0       2.00       5.0
# 2           500.0          1.000000            0.0       4.00       5.0
# 3           500.0          5.000000            0.0       2.00       5.0
# 115         500.0          2.500000            0.0       2.50       5.0
# 36          500.0          1.000000            0.0       3.00       5.0
# 37          500.0          1.000000            0.0       3.00       5.0
# 38          500.0          2.000000            0.0       3.00       5.0
# 39          500.0          2.000000            0.0       3.00       5.0
# 124         500.0          1.500000            0.0       3.00       5.0
# 63          300.0          2.000000            0.0       3.00       5.0
# 64          300.0          2.000000            0.0       3.00       5.0
# 65          300.0          2.000000            0.0       3.00       5.0
# 66          300.0          2.000000            0.0       3.00       5.0
# 133         300.0          2.000000            0.0       3.00       5.0
# 87          300.0          2.000000            0.0       3.00       5.0
# 88          300.0          2.000000            0.0       3.00       5.0
# 89          300.0          2.000000            0.0       3.00       5.0
# 90          300.0          2.000000            0.0       3.00       5.0
# 142         300.0          2.000000            0.0       3.00       5.0
# 4           500.0          5.000000            0.0       1.00       5.0
# 5           500.0          2.000000            0.0       1.00       5.0
# 6           500.0          4.000000            0.0       3.00       5.0
# 7           500.0          5.000000            0.0       5.00       5.0
# 116         500.0          4.000000            0.0       2.50       5.0
# 40          500.0          1.000000            0.0       3.00       5.0
# 41          500.0          1.000000            0.0       3.00       5.0
# 42          500.0          2.000000            0.0       3.00       5.0
# 43          500.0          1.000000            0.0       3.00       5.0
# 125         500.0          1.250000            0.0       3.00       5.0
# 67          300.0          1.000000            0.0       3.00       5.0
# 68          300.0          2.000000            0.0       3.00       5.0
# 69          300.0          1.000000            0.0       3.00       5.0
# 70          300.0          1.000000            0.0       3.00       5.0
# 134         300.0          1.250000            0.0       3.00       5.0
# 91          300.0          2.000000            0.0       3.00       5.0
# 92          300.0          2.000000            0.0       3.00       5.0
# 93          300.0          1.000000            0.0       3.00       5.0
# 94          300.0          2.000000            0.0       3.00       5.0
# 143         300.0          1.750000            0.0       3.00       5.0
# 8           300.0          3.000000            0.0       3.00       5.0
# 9           300.0          3.000000            0.0       1.00       5.0
# 10          300.0          4.000000            0.0       3.00       5.0
# 120         450.0          1.000000            0.0       3.00       5.0
# 56          300.0          1.000000            0.0       3.00       5.0
# 57          300.0          2.000000            0.0       3.00       5.0
# 58          300.0          1.000000            0.0       3.00       5.0
# 129         300.0          1.333333            0.0       3.00       5.0
# 107         300.0          1.000000            0.0       3.00       5.0
# 108         200.0          1.000000            0.0       3.00       5.0
# 109         200.0          2.000000            0.0       3.00       5.0
# 110         200.0          1.000000            0.0       3.00       5.0
# 147         225.0          1.250000            0.0       3.00       5.0
# 24          700.0          4.000000            0.0       5.00       5.0
# 25          700.0          1.000000            0.0       3.00       5.0
# 26          700.0          5.000000            0.0       4.00       5.0
# 27          700.0          4.000000            0.0       3.00       5.0
# 121         700.0          3.500000            0.0       3.75       5.0
# 59          700.0          2.000000            0.0       3.00       5.0
# 60          700.0          2.000000            0.0       3.00       5.0
# 61          700.0          1.000000            0.0       3.00       5.0
# 62          700.0          1.000000            0.0       3.00       5.0
# 130         700.0          1.500000            0.0       3.00       5.0
# 83          300.0          2.000000            0.0       3.00       5.0
# 84          300.0          2.000000            0.0       3.00       5.0
# 85          300.0          1.000000            0.0       3.00       5.0
# 86          300.0          2.000000            0.0       3.00       5.0
# 139         300.0          1.750000            0.0       3.00       5.0
# 111         100.0          1.000000            0.0       3.00       5.0
# 112         300.0          1.000000            0.0       3.00       5.0
# 113         300.0          1.000000            0.0       3.00       5.0
# 114         300.0          1.000000            0.0       3.00       5.0
# 148         250.0          1.000000            0.0       3.00       5.0
# 28          200.0          2.000000            0.0       3.00       5.0
# 29          200.0          2.000000            0.0       3.00       5.0
# 30          200.0          1.000000            0.0       3.00       5.0
# 31          200.0          1.000000            0.0       3.00       5.0
# 122         200.0          1.500000            0.0       3.00       5.0
# 32          700.0          2.000000            0.0       3.00       5.0
# 33          700.0          3.000000            0.0       3.00       5.0
# 34          700.0          2.000000            0.0       3.00       5.0
# 35          300.0          1.000000            0.0       3.00       5.0
# 123         600.0          2.000000            0.0       3.00       5.0
#
#      first_order  dropout  cycle meta_type  \
# 0            1.0   0.5000   96.0       all
# 1            1.0   0.5000   96.0       all
# 2            1.0   0.5000   96.0       all
# 3            1.0   0.5000   96.0       all
# 115          1.0   0.5000   96.0       NaN
# 36           1.0   0.5000   24.0       all
# 37           1.0   0.5000   24.0       all
# 38           1.0   0.5000   24.0       all
# 39           1.0   0.5000   24.0       all
# 124          1.0   0.5000   24.0       NaN
# 63           1.0   0.2000   24.0       all
# 64           1.0   0.2000   24.0       all
# 65           1.0   0.2000   24.0       all
# 66           1.0   0.2000   24.0       all
# 133          1.0   0.2000   24.0       NaN
# 87           1.0   0.1000   24.0       all
# 88           1.0   0.1000   24.0       all
# 89           1.0   0.1000   24.0       all
# 90           1.0   0.1000   24.0       all
# 142          1.0   0.1000   24.0       NaN
# 4            1.0   0.5000   96.0       all
# 5            1.0   0.5000   96.0       all
# 6            1.0   0.5000   96.0       all
# 7            1.0   0.5000   96.0       all
# 116          1.0   0.5000   96.0       NaN
# 40           1.0   0.4500   24.0       all
# 41           1.0   0.6000   24.0       all
# 42           1.0   0.6000   24.0       all
# 43           1.0   0.6000   24.0       all
# 125          1.0   0.5625   24.0       NaN
# 67           1.0   0.2000   24.0       all
# 68           1.0   0.2000   24.0       all
# 69           1.0   0.2000   24.0       all
# 70           1.0   0.2000   24.0       all
# 134          1.0   0.2000   24.0       NaN
# 91           1.0   0.1000   24.0       all
# 92           1.0   0.1000   24.0       all
# 93           1.0   0.1000   24.0       all
# 94           1.0   0.1000   24.0       all
# 143          1.0   0.1000   24.0       NaN
# 8            1.0   0.5000   24.0       all
# 9            1.0   0.5000   24.0       all
# 10           1.0   0.5000   24.0       all
# 11           1.0   0.5000   24.0       all
# 117          1.0   0.5000   24.0       NaN
# 44           1.0   0.2000   24.0       all
# 45           1.0   0.2000   24.0       all
# 46           1.0   0.2000   24.0       all
# 47           1.0   0.7000   24.0       all
# 126          1.0   0.3250   24.0       NaN
# 71           1.0   0.3000   24.0       all
# 72           1.0   0.3000   24.0       all
# 73           1.0   0.3000   24.0       all
# 74           1.0   0.3000   24.0       all
# 135          1.0   0.3000   24.0       NaN
# 95           1.0   0.1000   24.0       all
# 96           1.0   0.1000   24.0       all
# 97           1.0   0.1000   24.0       all
# 98           1.0   0.1000   24.0       all
# 144          1.0   0.1000   24.0       NaN
# 12           1.0   0.5000   24.0       all
# 13           1.0   0.5000   24.0       all
# 14           1.0   0.5000   24.0       all
# 15           1.0   0.5000   24.0       all
# 118          1.0   0.5000   24.0       NaN
# 48           1.0   0.5500   24.0       all
# 49           1.0   0.5500   24.0       all
# 50           1.0   0.5500   24.0       all
# 51           1.0   0.5500   24.0       all
# 127          1.0   0.5500   24.0       NaN
# 75           1.0   0.3000   24.0       all
# 76           1.0   0.3000   24.0       all
# 77           1.0   0.3000   24.0       all
# 78           1.0   0.3000   24.0       all
# 136          1.0   0.3000   24.0       NaN
# 99           1.0   0.1000   24.0       all
# 100          1.0   0.1000   24.0       all
# 101          1.0   0.1000   24.0       all
# 102          1.0   0.1000   24.0       all
# 145          1.0   0.1000   24.0       NaN
# 16           1.0   0.0000  168.0       all
# 17           1.0   0.0000  168.0       all
# 18           1.0   0.0000  168.0       all
# 19           1.0   0.0000  168.0       all
# 119          1.0   0.0000  168.0       NaN
# 52           1.0   0.4500   24.0       all
# 53           1.0   0.4500   24.0       all
# 54           1.0   0.4500   24.0       all
# 55           1.0   0.4500   24.0       all
# 128          1.0   0.4500   24.0       NaN
# 79           1.0   0.2000   24.0       all
# 80           1.0   0.2000   24.0       all
# 81           1.0   0.2000   24.0       all
# 82           1.0   0.2000   24.0       all
# 137          1.0   0.2000   24.0       NaN
# 103          1.0   0.1000   24.0       all
# 104          1.0   0.1000   24.0       all
# 105          1.0   0.1000   24.0       all
# 106          1.0   0.1000   24.0       all
# 146          1.0   0.1000   24.0       NaN
# 20           1.0   0.0000  168.0       all
# 21           1.0   0.0000  168.0       all
# 22           1.0   0.0000  168.0       all
# 23           1.0   0.0000  168.0       all
# 120          1.0   0.0000  168.0       NaN
# 56           1.0   0.3000   24.0       all
# 57           1.0   0.3000   24.0       all
# 58           1.0   0.3000   24.0       all
# 129          1.0   0.3000   24.0       NaN
# 107          1.0   0.1000   24.0       all
# 108          1.0   0.1000   24.0       all
# 109          1.0   0.1000   24.0       all
# 110          1.0   0.1000   24.0       all
# 147          1.0   0.1000   24.0       NaN
# 24           1.0   0.5000  144.0       all
# 25           1.0   0.5000  144.0       all
# 26           1.0   0.5000  144.0       all
# 27           1.0   0.5000  144.0       all
# 121          1.0   0.5000  144.0       NaN
# 59           1.0   0.4000   24.0       all
# 60           1.0   0.5000   24.0       all
# 61           1.0   0.5000   24.0       all
# 62           1.0   0.6000   24.0       all
# 130          1.0   0.5000   24.0       NaN
# 83           1.0   0.2000   24.0       all
# 84           1.0   0.2000   24.0       all
# 85           1.0   0.2000   24.0       all
# 86           1.0   0.2000   24.0       all
# 139          1.0   0.2000   24.0       NaN
# 111          1.0   0.1000   24.0       all
# 112          1.0   0.1000   24.0       all
# 113          1.0   0.1000   24.0       all
# 114          1.0   0.1000   24.0       all
# 148          1.0   0.1000   24.0       NaN
# 28           1.0   0.0000  288.0       all
# 29           1.0   0.0000  288.0       all
# 30           1.0   0.0000  288.0       all
# 31           1.0   0.0000  288.0       all
# 122          1.0   0.0000  288.0       NaN
# 32           1.0   0.0000  288.0       all
# 33           1.0   0.0000  288.0       all
# 34           1.0   0.0000  288.0       all
# 35           1.0   0.0000  288.0       all
# 123          1.0   0.0000  288.0       NaN
#
#                                                exp_dir
# 0    /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 1    /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 2    /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 3    /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 115                                                NaN
# 36   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 37   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 38   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 39   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 124                                                NaN
# 63   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 64   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 65   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 66   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 133                                                NaN
# 87   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 88   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 89   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 90   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 142                                                NaN
# 4    /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 5    /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 6    /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 7    /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 116                                                NaN
# 40   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 41   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 42   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 43   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 125                                                NaN
# 67   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 68   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 69   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 70   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 134                                                NaN
# 91   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 92   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 93   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 94   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 143                                                NaN
# 8    /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 9    /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 10   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 11   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 117                                                NaN
# 44   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 45   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 46   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 47   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 126                                                NaN
# 71   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 72   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 73   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 74   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 135                                                NaN
# 95   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 96   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 97   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 98   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 144                                                NaN
# 12   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 13   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 14   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 15   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 118                                                NaN
# 48   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 49   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 50   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 51   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 127                                                NaN
# 75   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 76   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 77   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 78   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 136                                                NaN
# 99   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 100  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 101  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 102  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 145                                                NaN
# 16   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 17   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 18   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 19   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 119                                                NaN
# 52   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 53   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 54   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 55   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 128                                                NaN
# 79   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 80   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 81   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 82   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 137                                                NaN
# 103  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 104  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 105  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 106  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 146                                                NaN
# 20   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 21   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 22   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 23   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 120                                                NaN
# 56   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 57   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 58   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 129                                                NaN
# 107  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 108  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 109  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 110  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 147                                                NaN
# 24   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 25   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 26   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 27   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 121                                                NaN
# 59   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 60   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 61   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 62   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 130                                                NaN
# 83   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 84   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 85   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 86   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 139                                                NaN
# 111  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 112  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 113  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 114  /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 148                                                NaN
# 28   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 29   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 30   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 31   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 122                                                NaN
# 32   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 33   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 34   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 35   /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/P...
# 123                                                NaN

# %%
save_root = '/mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/stats_ML3'
os.makedirs(save_root, exist_ok=True)
dfconfig = pd.read_csv(f"{save_root}/finetune_best.csv")

for model in ['TQNet']:
    for dst in ['ETTh1', 'ETTh2', 'ETTm1', 'ETTm2', 'ECL', 'Weather']:
        print(f"Model: {model}, Data ID: {dst}")
        configs = ['    case $pl in']
        for pl in [96, 192, 336, 720]:
            _df = dfconfig[(dfconfig.model == model) & (dfconfig.data_id == dst) & (dfconfig.pred_len == pl)]
            print(_df.exp_dir.values[0])
            conf = _df[['learning_rate', 'inner_lr', 'meta_lr', 'warmup_steps', 'max_norm', 'num_tasks', 'overlap_ratio', 'meta_inner_steps', 'reg_lambda', 'batch_size', 'auxi_batch_size', 'lradj', 'rec_lambda', 'auxi_loss', 'meta_type']].to_numpy().tolist()[0]
            assert conf[14] == 'all'
            conf_str = conf_str = f"        {pl}) lr={conf[0]} lr_inner={conf[1]} lr_meta={conf[2]} meta_steps={conf[3]} max_norm={conf[4]} num_tasks={conf[5]} overlap_ratio={conf[6]} meta_inner_steps={conf[7]} reg_lambda={conf[8]} batch_size={conf[9]} auxi_batch_size={conf[10]} lradj={conf[11]} lambda={conf[12]} auxi_loss={conf[13]};;"

            configs.append(conf_str)
        configs.append("    esac")
        print('\n'.join(configs))
        print('\n\n')
        
    for dst in ['PEMS03', 'PEMS08']:
        print(f"Model: {model}, Data ID: {dst}")
        configs = ['    case $pl in']
        for pl in [12, 24, 36, 48]:
            _df = dfconfig[(dfconfig.model == model) & (dfconfig.data_id == dst) & (dfconfig.pred_len == pl)]
            print(_df.exp_dir.values[0])
            conf = _df[['learning_rate', 'inner_lr', 'meta_lr', 'warmup_steps', 'max_norm', 'num_tasks', 'overlap_ratio', 'meta_inner_steps', 'reg_lambda', 'batch_size', 'auxi_batch_size', 'lradj', 'rec_lambda', 'auxi_loss', 'meta_type']].to_numpy().tolist()[0]
            assert conf[14] == 'all'
            conf_str = conf_str = f"        {pl}) lr={conf[0]} lr_inner={conf[1]} lr_meta={conf[2]} meta_steps={conf[3]} max_norm={conf[4]} num_tasks={conf[5]} overlap_ratio={conf[6]} meta_inner_steps={conf[7]} reg_lambda={conf[8]} batch_size={conf[9]} auxi_batch_size={conf[10]} lradj={conf[11]} lambda={conf[12]} auxi_loss={conf[13]};;"

            configs.append(conf_str)
        configs.append("    esac")
        print('\n'.join(configs))
        print('\n\n')
# Out:
# Model: TQNet, Data ID: ETTh1
# /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/results_ML3/finetune/TQNet_ETTh1_96_1.0_0.0_0.005_0.005_0.2_type1_30_5_32_64_0.0_5.0_3_0.0_3_MSE_24_0.5_linear_1_1_300
# /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/results_ML3/finetune/TQNet_ETTh1_192_1.0_0.0_0.005_0.005_0.02_type1_30_5_32_64_0.0_5.0_1_0.0_3_MSE_24_0.5_linear_1_1_300
# /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/results_ML3/finetune/TQNet_ETTh1_336_1.0_0.0_0.002_0.002_0.01_type1_30_5_32_64_0.0_5.0_3_0.0_4_MSE_24_0.5_linear_1_1_300
# /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/results_ML3/finetune/TQNet_ETTh1_720_1.0_0.0_0.005_0.005_0.01_type1_30_5_32_64_0.0_5.0_5_0.0_2_MSE_24_0.5_linear_1_1_300
#     case $pl in
#         96) lr=0.005 lr_inner=0.005 lr_meta=0.2 meta_steps=300 max_norm=5.0 num_tasks=3 overlap_ratio=0.0 meta_inner_steps=3 reg_lambda=0.0 batch_size=32 auxi_batch_size=64 lradj=type1 lambda=1.0 auxi_loss=MSE;;
#         192) lr=0.005 lr_inner=0.005 lr_meta=0.02 meta_steps=300 max_norm=5.0 num_tasks=1 overlap_ratio=0.0 meta_inner_steps
linear_1_1_700
# /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/results_ML3/finetune/TQNet_PEMS08_36_1.0_0.0_0.003_0.003_0.02_type1_30_5_32_64_0.0_5.0_3_0.0_2_MSE_288_0.0_linear_1_1_700
# /mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/results_ML3/finetune/TQNet_PEMS08_48_1.0_0.0_0.003_0.003_0.03_type1_30_5_32_64_0.0_5.0_3_0.0_1_MSE_288_0.0_linear_1_1_300
#     case $pl in
#         12) lr=0.003 lr_inner=0.003 lr_meta=0.01 meta_steps=700 max_norm=5.0 num_tasks=3 overlap_ratio=0.0 meta_inner_steps=2 reg_lambda=0.0 batch_size=32 auxi_batch_size=64 lradj=type1 lambda=1.0 auxi_loss=MSE;;
#         24) lr=0.003 lr_inner=0.003 lr_meta=0.02 meta_steps=700 max_norm=5.0 num_tasks=3 overlap_ratio=0.0 meta_inner_steps=3 reg_lambda=0.0 batch_size=32 auxi_batch_size=64 lradj=type1 lambda=1.0 auxi_loss=MSE;;
#         36) lr=0.003 lr_inner=0.003 lr_meta=0.02 meta_steps=700 max_norm=5.0 num_tasks=3 overlap_ratio=0.0 meta_inner_steps=2 reg_lambda=0.0 batch_size=32 auxi_batch_size=64 lradj=type1 lambda=1.0 auxi_loss=MSE;;
#         48) lr=0.003 lr_inner=0.003 lr_meta=0.03 meta_steps=300 max_norm=5.0 num_tasks=3 overlap_ratio=0.0 meta_inner_steps=1 reg_lambda=0.0 batch_size=32 auxi_batch_size=64 lradj=type1 lambda=1.0 auxi_loss=MSE;;
#     esac

# %% [markdown]
# # report to latex

# %% [markdown]
# ## load and merge data

# %%
save_root = '/mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/logs'
dfb = pd.read_csv(f"{save_root}/baselines_chosen.csv")

min_mode = 'each'
columns = ['model', 'data_id', 'learning_rate', 'batch_size', 'patience', 'individual', 'train_epochs']
if min_mode == 'group':
    mse_mean = dfb.groupby(columns)['mse'].mean().reset_index()
    idx = mse_mean.groupby(['model', 'data_id'])['mse'].idxmin()
    best_model = mse_mean.loc[idx]
    dfb = dfb.merge(best_model[columns], on=columns, how='inner')
elif min_mode == 'each':
    min_mse_idx = dfb.groupby(['model', 'data_id', 'pred_len'])['mse'].idxmin()
    dfb = dfb.loc[min_mse_idx]

dfb = dfb[['model', 'pred_len', 'data_id', 'mse', 'mae']]
datasets = ['ETTm1', 'ETTm2', 'ETTh1', 'ETTh2', 'ECL', 'Weather', 'PEMS03', 'PEMS08']
dfb = dfb[dfb['data_id'].isin(datasets)]


save_root = '/mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/stats_ML3'
dff = pd.read_csv(f'{save_root}/finetune_best.csv')

dff = dff[
    ((dff.data_id == 'ETTm1') & (dff.model == 'TQNet')) |
    ((dff.data_id == 'ETTm2') & (dff.model == 'TQNet')) |
    ((dff.data_id == 'ETTh1') & (dff.model == 'TQNet')) |
    ((dff.data_id == 'ETTh2') & (dff.model == 'TQNet')) |
    ((dff.data_id == 'ECL') & (dff.model == 'TQNet')) |
    # ((dff.data_id == 'Traffic') & (dff.model == 'TQNet')) |
    ((dff.data_id == 'Weather') & (dff.model == 'TQNet')) |
    ((dff.data_id == 'PEMS03') & (dff.model == 'TQNet')) |
    ((dff.data_id == 'PEMS08') & (dff.model == 'TQNet'))
]

dff['model'] = 'QDF'
dff.to_csv(f"{save_root}/long_term.csv", index=False)
dff = dff[['model', 'pred_len', 'data_id', 'mse', 'mae']]

dft = pd.concat([dfb, dff], axis=0)

# dst_order = ['ETTm1', 'ETTm2', 'ETTh1', 'ETTh2', 'ECL', 'Traffic', 'Weather', 'PEMS03', 'PEMS08']
dst_order = ['ETTm1', 'ETTm2', 'ETTh1', 'ETTh2', 'ECL', 'Weather', 'PEMS03', 'PEMS08']
dft['data_id'] = pd.Categorical(dft['data_id'], categories=dst_order, ordered=True)

model_order = ['QDF', 'TQNet', 'PDF', 'Fredformer', 'iTransformer', 'FreTS', 'TimesNet', 'MICN', 'TiDE', 'PatchTST', 'DLinear']
dft = dft[dft['model'].isin(model_order)]
dft['model'] = pd.Categorical(dft['model'], categories=model_order, ordered=True)

dft_avg = dft.groupby(['model', 'data_id']).mean(numeric_only=True).reset_index()
dft_avg['pred_len'] = 'Avg'

dft = pd.concat([dft, dft_avg]).reset_index(drop=True)
dft.sort_values(by=['model', 'data_id', 'pred_len'], inplace=True)

dft_show = dft.set_index(['data_id', 'pred_len', 'model']).unstack('model').swaplevel(axis=1)
columns = []
for model in dft_show.columns.levels[0]:
    columns.append((model, 'mse'))
    columns.append((model, 'mae'))
dft_show = dft_show[columns]
dft_show
# Out:
# /tmp/ipykernel_1486806/2195932971.py:49: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dft_avg = dft.groupby(['model', 'data_id']).mean(numeric_only=True).reset_index()
# model                  QDF               TQNet                 PDF            \
#                        mse       mae       mse       mae       mse       mae
# data_id pred_len
# ETTm1   96        0.306602  0.348971  0.310382  0.351721  0.326234  0.363356
#         192       0.352414  0.376268  0.356100  0.377443  0.364817  0.381136
#         336       0.382595  0.397512  0.387569  0.399900  0.396639  0.402112
#         720       0.441163  0.434478  0.450021  0.436546  0.458370  0.437322
#         Avg       0.370693  0.389307  0.376018  0.391403  0.386515  0.395981
# ETTm2   96        0.170291  0.252600  0.174746  0.255768  0.176168  0.263647
#         192       0.233855  0.293836  0.242704  0.300489  0.245158  0.310199
#         336       0.290130  0.331435  0.297452  0.336435  0.305491  0.345152
#         720       0.386822  0.388532  0.394070  0.393085  0.403959  0.403241
#         Avg       0.270274  0.316601  0.277243  0.321444  0.282694  0.330560
# ETTh1   96        0.365111  0.388897  0.372007  0.391440  0.388068  0.400122
#         192       0.427475  0.421499  0.430498  0.424173  0.440350  0.428146
#         336       0.465918  0.448515  0.486262  0.454420  0.483253  0.448762
#         720       0.466485  0.466534  0.506832  0.485931  0.495008  0.481555
#         Avg       0.431247  0.431361  0.448900  0.438991  0.451670  0.439646
# ETTh2   96        0.285880  0.337922  0.293373  0.342665  0.290784  0.340032
#         192       0.361035  0.388219  0.363695  0.390391  0.374348  0.390743
#         336       0.407637  0.422494  0.411333  0.424371  0.413972  0.425852
#         720       0.419220  0.438823  0.429976  0.443821  0.421089  0.439893
#         Avg       0.368443  0.396864  0.374594  0.400312  0.375048  0.399130
# ECL     96        0.134708  0.228838  0.143456  0.237354  0.175417  0.259347
#         192       0.153000  0.244973  0.160641  0.252081  0.181722  0.265927
#         336       0.169068  0.262404  0.178238  0.269703  0.197201  0.281979
#         720       0.201599  0.290306  0.217629  0.302696  0.237404  0.315331
#         Avg       0.164594  0.256630  0.174991  0.265458  0.197936  0.280646
# Weather 96        0.158300  0.200693  0.159965  0.202723  0.181140  0.221251
#         192       0.206637  0.244936  0.209872  0.247166  0.231525  0.262294
#         336       0.262811  0.286290  0.266696  0.288953  0.285225  0.299993
#         720       0.342250  0.339154  0.346121  0.342470  0.360232  0.348378
#         Avg       0.242499  0.267768  0.245663  0.270328  0.264530  0.282979
# PEMS03  12        0.064309  0.167092  0.097305  0.179638  0.091645  0.204271
#         24        0.080374  0.188680  0.098929  0.204429  0.148696  0.260927
#         36        0.097987  0.208369  0.123181  0.229999  0.210095  0.313705
#         48        0.111981  0.223476  0.157448  0.255610  0.274832  0.364260
#         Avg       0.088663  0.196904  0.119216  0.217419  0.181317  0.285790
# PEMS08  12        0.074487  0.175849  0.078706  0.182539  0.099847  0.208661
#         24        0.104101  0.207774  0.117204  0.222451  0.167697  0.272787
#         192       0.304153  0.285455  0.338665  0.279695  0.355772
#         336       0.342926  0.308646  0.347435  0.375375  0.420250
#         720       0.398233  0.436623  0.421665  0.525772  0.508116
#         Avg       0.327573  0.302767  0.343509  0.342181  0.391771
# ETTh1   96        0.394970  0.380695  0.400148  0.388942  0.403672
#         192       0.424741  0.449703  0.442750  0.442218  0.439876
#         336       0.446970  0.500856  0.470034  0.488474  0.466596
#         720       0.471415  0.504114  0.492286  0.505058  0.502427
#         Avg       0.434524  0.458842  0.451305  0.456173  0.453143
# ETTh2   96        0.339774  0.298961  0.349385  0.330024  0.382585
#         192       0.391642  0.382776  0.403677  0.439167  0.449528
#         336       0.427378  0.438919  0.443815  0.589380  0.537515
#         720       0.445574  0.437883  0.455288  0.757178  0.626219
#         Avg       0.401092  0.389635  0.413041  0.528937  0.498962
# ECL     96        0.274012  0.169720  0.263821  0.197025  0.282377
#         192       0.276812  0.179125  0.273064  0.196554  0.285564
#         336       0.291828  0.194991  0.287728  0.209465  0.300937
#         720       0.325082  0.234310  0.319622  0.244849  0.333502
#         Avg       0.291933  0.194536  0.286059  0.211973  0.300595
# Weather 96        0.232393  0.188809  0.230401  0.193972  0.253232
#         192       0.270194  0.227930  0.261806  0.237857  0.296273
#         336       0.306784  0.288298  0.304599  0.281825  0.332035
#         720       0.353228  0.362152  0.353758  0.347499  0.384916
#         Avg       0.290650  0.266797  0.287641  0.265288  0.316614
# PEMS03  12        0.225791  0.092263  0.209862  0.105025  0.220418
#         24        0.322048  0.144398  0.262728  0.182893  0.296870
#         36        0.417677  0.200407  0.309254  0.257679  0.361320
#         48        0.516158  0.244578  0.344490  0.318706  0.410237
#         Avg       0.370418  0.170412  0.281583  0.216076  0.322211
# PEMS08  12        0.233324  0.106115  0.222772  0.112962  0.225221
#         24        0.325121  0.161947  0.275484  0.198670  0.302117
#         36        0.427015  0.233724  0.330517  0.294509  0.370639
#         48        0.526627  0.301158  0.382042  0.388941  0.428529
#         Avg       0.378022  0.200736  0.302704  0.248770  0.331627

# %% [markdown]
# ## save to latex table

# %%
save_root = "/mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/stats_ML3"
# dft_show.to_latex(f"{save_root}/long_term.tex")



# dst_order = ['ETTm1', 'ETTm2', 'ETTh1', 'ETTh2', 'ECL', 'Traffic', 'Weather', 'PEMS03', 'PEMS08']
dst_order = ['ETTm1', 'ETTm2', 'ETTh1', 'ETTh2', 'ECL', 'Weather', 'PEMS03', 'PEMS08']
model_order = ['QDF', 'TQNet', 'PDF', 'Fredformer', 'iTransformer', 'FreTS', 'TimesNet', 'MICN', 'TiDE', 'PatchTST', 'DLinear']
# 初始化统计字典：每个模型的MSE第1次数和MAE第1次数
mse_count = {model: 0 for model in model_order}
mae_count = {model: 0 for model in model_order}


contents = []
stats_contents = []  # 存储统计行内容
for dst in dst_order:
    dfi = dft[dft.data_id == dst]

    dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
    dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')

    # MSE第1名：mse_rank=1的模型
    mse_first_models = dfi[dfi['mse_rank'] == 1]['model']
    for model in mse_first_models:
        if model in mse_count:  # 确保模型在model_order中
            mse_count[model] += 1
    
    # MAE第1名：mae_rank=1的模型
    mae_first_models = dfi[dfi['mae_rank'] == 1]['model']
    for model in mae_first_models:
        if model in mae_count:
            mae_count[model] += 1

    for metric in ['mse', 'mae']:
        dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
        # 按排名标记：第1名→\bst{}，第2名→\subbst{}，其他→原格式
        conditions = [dfi[f'{metric}_rank'] == 1, dfi[f'{metric}_rank'] == 2]
        choices = [r'\bst{' + dfi[f'{metric}_3f'] + '}', r'\subbst{' + dfi[f'{metric}_3f'] + '}']
        dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
    dfi = dfi[['model', 'pred_len', 'mse_processed', 'mae_processed']]
    dfi.columns = ['model', 'pred_len', 'mse', 'mae']
    dfi['mse'] = dfi['mse'].apply(lambda x: r"\scalea{" + x + "}")  # 应用\scalea
    dfi['mae'] = dfi['mae'].apply(lambda x: r"\scalea{" + x + "}")
    for i, (pl, group) in enumerate(dfi.groupby('pred_len')):
        if i == 0:
            title = r'\multirow{5}{*}{{\rotatebox{90}{\scalebox{0.95}{' + dst + '}}}}'
            contents.append(title)
        line = f"& {pl} "
        for j, row in enumerate(group.itertuples(index=False)):
            line += f"& {row.mse} & {row.mae}"
        line += " \\\\"
        contents.append(line)
        if i == 3:
            contents.append(r"\cmidrule(lr){2-24}")
        elif i  == 4:
            contents.append("\\midrule\n")

stats_title = r"\multicolumn{2}{c|}{\scalea{{$1^{\text{st}}$ Count}}}"  # 标题：合并前两列
stats_values = []
for model in model_order:
    mse = mse_count[model]
    mae = mae_count[model]
    # 次数>0时用\bst{}标记，否则0
    mse_str = r"\scalea{\bst{" + str(mse) + "}}" if mse > 0 else r"\scalea{" + str(mse) + "}"
    mae_str = r"\scalea{\bst{" + str(mae) + "}}" if mae > 0 else r"\scalea{" + str(mae) + "}"
    stats_values.append(f"{mse_str} & {mae_str}")  # 每个模型的MSE/MAE次数
# 合并统计行
stats_line = f"{stats_title} & {' & '.join(stats_values)} \\\\"
stats_contents.append(stats_line)

print(sum(mse_count.values()), sum(mae_count.values()))
print(max(mse_count.values()), max(mae_count.values()))

with open(f"{save_root}/long_term.tex", "w") as f:
    f.write("\n".join(contents + stats_contents))
# Out:
# 40 40
# 39 39
# /tmp/ipykernel_1486806/975220537.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_1486806/975220537.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_1486806/975220537.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])

# %% [markdown]
# ## write avg

# %%
save_root = "/mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/stats_ML3"
# dft_show.to_latex(f"{save_root}/long_term.tex")



dst_order = ['ETTm1', 'ETTm2', 'ETTh1', 'ETTh2', 'ECL', 'Weather', 'PEMS03', 'PEMS08']
model_order = ['MetaDF', 'TQNet', 'PDF', 'Fredformer', 'iTransformer', 'FreTS', 'TimesNet', 'MICN', 'TiDE', 'PatchTST', 'DLinear']
# 初始化统计字典：每个模型的MSE第1次数和MAE第1次数
mse_count = {model: 0 for model in model_order}
mae_count = {model: 0 for model in model_order}


contents = []
stats_contents = []  # 存储统计行内容
for dst in dst_order:
    dfi = dft[dft.data_id == dst]

    dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
    dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')

    # MSE第1名：mse_rank=1的模型
    mse_first_models = dfi[dfi['mse_rank'] == 1]['model']
    for model in mse_first_models:
        if model in mse_count:  # 确保模型在model_order中
            mse_count[model] += 1
    
    # MAE第1名：mae_rank=1的模型
    mae_first_models = dfi[dfi['mae_rank'] == 1]['model']
    for model in mae_first_models:
        if model in mae_count:
            mae_count[model] += 1

    for metric in ['mse', 'mae']:
        dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
        # 按排名标记：第1名→\bst{}，第2名→\subbst{}，其他→原格式
        conditions = [dfi[f'{metric}_rank'] == 1, dfi[f'{metric}_rank'] == 2]
        choices = [r'\bst{' + dfi[f'{metric}_3f'] + '}', r'\subbst{' + dfi[f'{metric}_3f'] + '}']
        dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
    dfi = dfi[['model', 'pred_len', 'mse_processed', 'mae_processed']]
    dfi.columns = ['model', 'pred_len', 'mse', 'mae']
    dfi['mse'] = dfi['mse'].apply(lambda x: r"\scalea{" + x + "}")  # 应用\scalea
    dfi['mae'] = dfi['mae'].apply(lambda x: r"\scalea{" + x + "}")
    for i, (pl, group) in enumerate(dfi.groupby('pred_len')):
        if pl != 'Avg':
            continue
        line = r"\multicolumn{2}{l}{\scalea{" + dst + r"}}" + '\n'
        for j, row in enumerate(group.itertuples(index=False)):
            line += f"& {row.mse} & {row.mae}"
        line += " \\\\"
        contents.append(line)
    if dst != dst_order[-1]:
        contents.append("\\midrule")


with open(f"{save_root}/long_term_avg.tex", "w") as f:
    f.write("\n".join(contents))
print("\n".join(contents))
# Out:
# \multicolumn{2}{l}{\scalea{ETTm1}}
# & \scalea{\bst{0.371}} & \scalea{\bst{0.389}}& \scalea{\subbst{0.376}} & \scalea{\subbst{0.391}}& \scalea{0.387} & \scalea{0.396}& \scalea{0.387} & \scalea{0.398}& \scalea{0.411} & \scalea{0.414}& \scalea{0.414} & \scalea{0.421}& \scalea{0.438} & \scalea{0.430}& \scalea{0.396} & \scalea{0.421}& \scalea{0.413} & \scalea{0.407}& \scalea{0.389} & \scalea{0.400}& \scalea{0.403} & \scalea{0.407} \\
# \midrule
# \multicolumn{2}{l}{\scalea{ETTm2}}
# & \scalea{\bst{0.270}} & \scalea{\bst{0.317}}& \scalea{\subbst{0.277}} & \scalea{\subbst{0.321}}& \scalea{0.283} & \scalea{0.331}& \scalea{0.280} & \scalea{0.324}& \scalea{0.295} & \scalea{0.336}& \scalea{0.316} & \scalea{0.365}& \scalea{0.302} & \scalea{0.334}& \scalea{0.308} & \scalea{0.364}& \scalea{0.286} & \scalea{0.328}& \scalea{0.303} & \scalea{0.344}& \scalea{0.342} & \scalea{0.392} \\
# \midrule
# \multicolumn{2}{l}{\scalea{ETTh1}}
# & \scalea{\bst{0.431}} & \scalea{\bst{0.431}}& \scalea{0.449} & \scalea{0.439}& \scalea{0.452} & \scalea{0.440}& \scalea{\subbst{0.447}} & \scalea{\subbst{0.434}}& \scalea{0.452} & \scalea{0.448}& \scalea{0.489} & \scalea{0.474}& \scalea{0.472} & \scalea{0.463}& \scalea{0.533} & \scalea{0.519}& \scalea{0.448} & \scalea{0.435}& \scalea{0.459} & \scalea{0.451}& \scalea{0.456} & \scalea{0.453} \\
# \midrule
# \multicolumn{2}{l}{\scalea{ETTh2}}
# & \scalea{\bst{0.368}} & \scalea{\bst{0.397}}& \scalea{\subbst{0.375}} & \scalea{0.400}& \scalea{0.375} & \scalea{\subbst{0.399}}& \scalea{0.377} & \scalea{0.402}& \scalea{0.386} & \scalea{0.407}& \scalea{0.524} & \scalea{0.496}& \scalea{0.409} & \scalea{0.420}& \scalea{0.620} & \scalea{0.546}& \scalea{0.378} & \scalea{0.401}& \scalea{0.390} & \scalea{0.413}& \scalea{0.529} & \scalea{0.499} \\
# \midrule
# \multicolumn{2}{l}{\scalea{ECL}}
# & \scalea{\bst{0.165}} & \scalea{\bst{0.257}}& \scalea{\subbst{0.175}} & \scalea{\subbst{0.265}}& \scalea{0.198} & \scalea{0.281}& \scalea{0.191} & \scalea{0.284}& \scalea{0.179} & \scalea{0.270}& \scalea{0.199} & \scalea{0.288}& \scalea{0.212} & \scalea{0.306}& \scalea{0.192} & \scalea{0.302}& \scalea{0.215} & \scalea{0.292}& \scalea{0.195} & \scalea{0.286}& \scalea{0.212} & \scalea{0.301} \\
# \midrule
# \multicolumn{2}{l}{\scalea{Weather}}
# & \scalea{\bst{0.242}} & \scalea{\bst{0.268}}& \scalea{\subbst{0.246}} & \scalea{\subbst{0.270}}& \scalea{0.265} & \scalea{0.283}& \scalea{0.261} & \scalea{0.282}& \scalea{0.269} & \scalea{0.289}& \scalea{0.249} & \scalea{0.293}& \scalea{0.271} & \scalea{0.295}& \scalea{0.264} & \scalea{0.321}& \scalea{0.272} & \scalea{0.291}& \scalea{0.267} & \scalea{0.288}& \scalea{0.265} & \scalea{0.317} \\
# \midrule
# \multicolumn{2}{l}{\scalea{PEMS03}}
# & \scalea{\bst{0.089}} & \scalea{\bst{0.197}}& \scalea{0.119} & \scalea{\subbst{0.217}}& \scalea{0.181} & \scalea{0.286}& \scalea{0.146} & \scalea{0.260}& \scalea{0.122} & \scalea{0.233}& \scalea{0.149} & \scalea{0.261}& \scalea{0.126} & \scalea{0.230}& \scalea{\subbst{0.106}} & \scalea{0.223}& \scalea{0.316} & \scalea{0.370}& \scalea{0.170} & \scalea{0.282}& \scalea{0.216} & \scalea{0.322} \\
# \midrule
# \multicolumn{2}{l}{\scalea{PEMS08}}
# & \scalea{\bst{0.120}} & \scalea{\bst{0.221}}& \scalea{\subbst{0.139}} & \scalea{\subbst{0.240}}& \scalea{0.210} & \scalea{0.301}& \scalea{0.171} & \scalea{0.271}& \scalea{0.149} & \scalea{0.247}& \scalea{0.174} & \scalea{0.275}& \scalea{0.152} & \scalea{0.243}& \scalea{0.153} & \scalea{0.258}& \scalea{0.318} & \scalea{0.378}& \scalea{0.201} & \scalea{0.303}& \scalea{0.249} & \scalea{0.332} \\
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])

# %% [markdown]
# ## write avg

# %%
save_root = "/mnt/tidalfs-bdsz01/usr/panlicheng/workspace/ProjDF-Meta/stats_ML3"
# dft_show.to_latex(f"{save_root}/long_term.tex")



dst_order = ['ETTm1', 'ETTm2', 'ETTh1', 'ETTh2', 'ECL', 'Weather', 'PEMS03', 'PEMS08']
model_order = ['MetaDF', 'TQNet', 'PDF', 'Fredformer', 'iTransformer', 'FreTS', 'TimesNet', 'MICN', 'TiDE', 'PatchTST', 'DLinear']
# 初始化统计字典：每个模型的MSE第1次数和MAE第1次数
mse_count = {model: 0 for model in model_order}
mae_count = {model: 0 for model in model_order}


contents = []
stats_contents = []  # 存储统计行内容
for dst in dst_order:
    dfi = dft[dft.data_id == dst]

    dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
    dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')

    # MSE第1名：mse_rank=1的模型
    mse_first_models = dfi[dfi['mse_rank'] == 1]['model']
    for model in mse_first_models:
        if model in mse_count:  # 确保模型在model_order中
            mse_count[model] += 1
    
    # MAE第1名：mae_rank=1的模型
    mae_first_models = dfi[dfi['mae_rank'] == 1]['model']
    for model in mae_first_models:
        if model in mae_count:
            mae_count[model] += 1

    for metric in ['mse', 'mae']:
        dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
        # 按排名标记：第1名→\bst{}，第2名→\subbst{}，其他→原格式
        conditions = [dfi[f'{metric}_rank'] == 1, dfi[f'{metric}_rank'] == 2]
        choices = [r'\bst{' + dfi[f'{metric}_3f'] + '}', r'\subbst{' + dfi[f'{metric}_3f'] + '}']
        dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
    dfi = dfi[['model', 'pred_len', 'mse_processed', 'mae_processed']]
    dfi.columns = ['model', 'pred_len', 'mse', 'mae']
    dfi['mse'] = dfi['mse'].apply(lambda x: r"\scalea{" + x + "}")  # 应用\scalea
    dfi['mae'] = dfi['mae'].apply(lambda x: r"\scalea{" + x + "}")
    for i, (pl, group) in enumerate(dfi.groupby('pred_len')):
        if pl != 'Avg':
            continue
        line = r"\multicolumn{2}{l}{\scalea{" + dst + r"}}" + '\n'
        for j, row in enumerate(group.itertuples(index=False)):
            line += f"& {row.mse} & {row.mae}"
        line += " \\\\"
        contents.append(line)
    if dst != dst_order[-1]:
        contents.append("\\midrule")


with open(f"{save_root}/long_term_avg.tex", "w") as f:
    f.write("\n".join(contents))
print("\n".join(contents))
# Out:
# \multicolumn{2}{l}{\scalea{ETTm1}}
# & \scalea{\bst{0.371}} & \scalea{\bst{0.389}}& \scalea{\subbst{0.376}} & \scalea{\subbst{0.391}}& \scalea{0.387} & \scalea{0.396}& \scalea{0.387} & \scalea{0.398}& \scalea{0.411} & \scalea{0.414}& \scalea{0.414} & \scalea{0.421}& \scalea{0.438} & \scalea{0.430}& \scalea{0.396} & \scalea{0.421}& \scalea{0.413} & \scalea{0.407}& \scalea{0.389} & \scalea{0.400}& \scalea{0.403} & \scalea{0.407} \\
# \midrule
# \multicolumn{2}{l}{\scalea{ETTm2}}
# & \scalea{\bst{0.270}} & \scalea{\bst{0.317}}& \scalea{\subbst{0.277}} & \scalea{\subbst{0.321}}& \scalea{0.283} & \scalea{0.331}& \scalea{0.280} & \scalea{0.324}& \scalea{0.295} & \scalea{0.336}& \scalea{0.316} & \scalea{0.365}& \scalea{0.302} & \scalea{0.334}& \scalea{0.308} & \scalea{0.364}& \scalea{0.286} & \scalea{0.328}& \scalea{0.303} & \scalea{0.344}& \scalea{0.342} & \scalea{0.392} \\
# \midrule
# \multicolumn{2}{l}{\scalea{ETTh1}}
# & \scalea{\bst{0.431}} & \scalea{\bst{0.431}}& \scalea{0.449} & \scalea{0.439}& \scalea{0.452} & \scalea{0.440}& \scalea{\subbst{0.447}} & \scalea{\subbst{0.434}}& \scalea{0.452} & \scalea{0.448}& \scalea{0.489} & \scalea{0.474}& \scalea{0.472} & \scalea{0.463}& \scalea{0.533} & \scalea{0.519}& \scalea{0.448} & \scalea{0.435}& \scalea{0.459} & \scalea{0.451}& \scalea{0.456} & \scalea{0.453} \\
# \midrule
# \multicolumn{2}{l}{\scalea{ETTh2}}
# & \scalea{\bst{0.368}} & \scalea{\bst{0.397}}& \scalea{\subbst{0.375}} & \scalea{0.400}& \scalea{0.375} & \scalea{\subbst{0.399}}& \scalea{0.377} & \scalea{0.402}& \scalea{0.386} & \scalea{0.407}& \scalea{0.524} & \scalea{0.496}& \scalea{0.409} & \scalea{0.420}& \scalea{0.620} & \scalea{0.546}& \scalea{0.378} & \scalea{0.401}& \scalea{0.390} & \scalea{0.413}& \scalea{0.529} & \scalea{0.499} \\
# \midrule
# \multicolumn{2}{l}{\scalea{ECL}}
# & \scalea{\bst{0.165}} & \scalea{\bst{0.257}}& \scalea{\subbst{0.175}} & \scalea{\subbst{0.265}}& \scalea{0.198} & \scalea{0.281}& \scalea{0.191} & \scalea{0.284}& \scalea{0.179} & \scalea{0.270}& \scalea{0.199} & \scalea{0.288}& \scalea{0.212} & \scalea{0.306}& \scalea{0.192} & \scalea{0.302}& \scalea{0.215} & \scalea{0.292}& \scalea{0.195} & \scalea{0.286}& \scalea{0.212} & \scalea{0.301} \\
# \midrule
# \multicolumn{2}{l}{\scalea{Weather}}
# & \scalea{\bst{0.242}} & \scalea{\bst{0.268}}& \scalea{\subbst{0.246}} & \scalea{\subbst{0.270}}& \scalea{0.265} & \scalea{0.283}& \scalea{0.261} & \scalea{0.282}& \scalea{0.269} & \scalea{0.289}& \scalea{0.249} & \scalea{0.293}& \scalea{0.271} & \scalea{0.295}& \scalea{0.264} & \scalea{0.321}& \scalea{0.272} & \scalea{0.291}& \scalea{0.267} & \scalea{0.288}& \scalea{0.265} & \scalea{0.317} \\
# \midrule
# \multicolumn{2}{l}{\scalea{PEMS03}}
# & \scalea{\bst{0.089}} & \scalea{\bst{0.197}}& \scalea{0.119} & \scalea{\subbst{0.217}}& \scalea{0.181} & \scalea{0.286}& \scalea{0.146} & \scalea{0.260}& \scalea{0.122} & \scalea{0.233}& \scalea{0.149} & \scalea{0.261}& \scalea{0.126} & \scalea{0.230}& \scalea{\subbst{0.106}} & \scalea{0.223}& \scalea{0.316} & \scalea{0.370}& \scalea{0.170} & \scalea{0.282}& \scalea{0.216} & \scalea{0.322} \\
# \midrule
# \multicolumn{2}{l}{\scalea{PEMS08}}
# & \scalea{\bst{0.120}} & \scalea{\bst{0.221}}& \scalea{\subbst{0.139}} & \scalea{\subbst{0.240}}& \scalea{0.210} & \scalea{0.301}& \scalea{0.171} & \scalea{0.271}& \scalea{0.149} & \scalea{0.247}& \scalea{0.174} & \scalea{0.275}& \scalea{0.152} & \scalea{0.243}& \scalea{0.153} & \scalea{0.258}& \scalea{0.318} & \scalea{0.378}& \scalea{0.201} & \scalea{0.303}& \scalea{0.249} & \scalea{0.332} \\
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mse_rank'] = dfi.groupby('pred_len')['mse'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi['mae_rank'] = dfi.groupby('pred_len')['mae'].rank(ascending=True, method='dense')
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
# /tmp/ipykernel_253782/3944324592.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_3f'] = dfi[metric].apply(lambda x: "{:.3f}".format(x))
# /tmp/ipykernel_253782/3944324592.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi[f'{metric}_processed'] = np.select(conditions, choices, default=dfi[f'{metric}_3f'])
